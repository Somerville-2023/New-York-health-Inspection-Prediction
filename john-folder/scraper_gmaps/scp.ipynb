# %%
import requests
from googlemaps import GoogleMapsScraper
from selenium.webdriver.common.by import By

# Function to get IP address without using Tor
def get_ip_without_tor():
    response = requests.get('http://httpbin.org/ip')
    ip_without_tor = response.json()['origin']
    print("IP without Tor:", ip_without_tor)
    return ip_without_tor

# Function to get IP address using Tor with the initialized WebDriver
def get_ip_with_tor(scraper):
    scraper.driver.get('http://httpbin.org/ip')
    response_text = scraper.driver.find_element(By.TAG_NAME, 'pre').text
    ip_with_tor = eval(response_text)['origin']
    print("IP with Tor:", ip_with_tor)
    return ip_with_tor

def test_tor_connection():
    print("Testing Tor connection...")

    # Initialize GoogleMapsScraper
    scraper = GoogleMapsScraper()

    # Get IP without Tor
    ip_without_tor = get_ip_without_tor()

    # Get IP with Tor
    ip_with_tor = get_ip_with_tor(scraper)

    # Check if the IP addresses are different
    if ip_without_tor != ip_with_tor:
        print("IP masking successful: Your IP address is being masked by Tor.")
    else:
        print("IP masking unsuccessful: Your IP address is not being masked by Tor.")

    # Close and quit the WebDriver
    # scraper.driver.quit()

    print("Test completed.")

# %%
test_tor_connection()
# Out:
# Testing Tor connection...
# IP without Tor: 75.81.146.166
# IP with Tor: 188.68.41.191
# IP masking successful: Your IP address is being masked by Tor.
# Test completed.

# %%
from stem import Signal
from stem.control import Controller

# %%
# !python scraper.py --N 20 --i places_scrape_rdy.csv --debug
# Out:
# Initializing GoogleMapsScraper...
# Starting __get_driver
# Initializing ChromeDriver...
# ChromeDriver successfully initialized.
# Starting __get_logger
# Initializing logger...
# Logger successfully initialized.
# GoogleMapsScraper initialized successfully.
# Entering GoogleMapsScraper context.
# Scraper initialized successfully.
# Testing Tor connection...
# IP without Tor: 75.81.146.166
# IP with Tor: 192.42.116.212
# IP masking successful: Your IP address is being masked by Tor.
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJ7bngQXZZwokRQtaUAwUwyJA
# Attempting to sort reviews...
# Starting sort_by
# Attempting to navigate to URL...
# URL navigation successful.
# Starting __scroll
# Successfully scrolled
# Starting __expand_reviews
# Successfully expanded reviews.
# Attempting to click sorting button...
# Sorting button clicked successfully.
# Attempting to select sorting option index 1...
# Sorting option selected successfully.
# Waiting for reviews to load after sorting...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJ7bngQXZZwokRQtaUAwUwyJA...
# [Scraping from review 0]
# Starting get_reviews
# Attempting to scroll to load reviews from offset: 0
# Starting scroll_reviews
# Successfully scrolled in scroll_reviews
# Attempting to expand review text...
# starting __expand_reviews_text
# starting to click more button
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Parsing expanded reviews...
# Processing review 0...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 0 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNGMDhHSkVnEAE', 'caption': None, 'relative_date': '10 hours ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 827897), 'rating': 5.0, 'username': 'Eddie Trujillo', 'n_review_user': '1', 'url_user': 'https://www.google.com/maps/contrib/106417660242410636199/reviews?hl=en', 'r_additional': ['Service: 5', 'Atmosphere: 5']}
# Processing review 1...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Error parsing n_reviews: 'NoneType' object has no attribute 'text'
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 1 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUNGM2NhcGpnRRAB', 'caption': None, 'relative_date': 'a day ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 828964), 'rating': 5.0, 'username': 'Mahamadou Asouman', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/107860253116472731345/reviews?hl=en', 'r_additional': ['Service: 5', 'Atmosphere: 5']}
# Processing review 2...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 2 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUNGbmVidnRRRRAB', 'caption': None, 'relative_date': 'a day ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 829513), 'rating': 5.0, 'username': 'sedjnie ritoe', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/117034400557310644264/reviews?hl=en', 'r_additional': []}
# Processing review 3...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Fabulous food
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 3 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNGNmY2Q0F3EAE', 'caption': 'Fabulous food', 'relative_date': '4 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 830495), 'rating': 5.0, 'username': 'Vibhuti Gedela', 'n_review_user': '20', 'url_user': 'https://www.google.com/maps/contrib/116188048624988352968/reviews?hl=en', 'r_additional': ['Service Dine in', 'Meal type Dinner', 'Price per person $50–100', 'Food: 5', 'Service: 4', 'Atmosphere: 4', 'Recommended dishes Muhammara, Chicken Kebab, Spicy Hummus, Baby Lamb Chops', 'Vegetarian options It would be nice if they could add more vegetarian options in the entrée']}
# Processing review 4...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Overrated.  Terrible service, the fault of the blond waiter who abandoned us all evening
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 4 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNGNmZEdEVnEAE', 'caption': 'Overrated.  Terrible service, the fault of the blond waiter who abandoned us all evening', 'relative_date': '4 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 831235), 'rating': 3.0, 'username': 'Giulia Passaniti', 'n_review_user': '107', 'url_user': 'https://www.google.com/maps/contrib/106110422644034715875/reviews?hl=en', 'r_additional': []}
# Processing review 5...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: The food was great, and Stephie was a wonderful server!
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 5 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUNGd2EyTG5nRRAB', 'caption': 'The food was great, and Stephie was a wonderful server!', 'relative_date': '4 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 832333), 'rating': 5.0, 'username': 'Jimmy Yang', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/100602979700893878888/reviews?hl=en', 'r_additional': ['Food: 5', 'Service: 5', 'Atmosphere: 5']}
# Processing review 6...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Some of the best food I’ve ever had in NY, our server Ben was great. Highly recommend!
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 6 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUNGdG9XY2h3RRAB', 'caption': 'Some of the best food I’ve ever had in NY, our server Ben was great. Highly recommend!', 'relative_date': '5 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 833842), 'rating': 5.0, 'username': 'Rohan Dayal', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/104091873632460262589/reviews?hl=en', 'r_additional': ['Service Dine in', 'Meal type Dinner', 'Price per person $30–50', 'Food: 5', 'Service: 5', 'Atmosphere: 5', "Recommended dishes Za'Atar Manouche, Chicken Kebab, Spicy Hummus"]}
# Processing review 7...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Incredible food, amazing service by Ben!
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 7 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNGdHBuVk9BEAE', 'caption': 'Incredible food, amazing service by Ben!', 'relative_date': '5 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 835035), 'rating': 5.0, 'username': 'Sai Harshit Chintalapati', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/112541273074848616842/reviews?hl=en', 'r_additional': ['Food: 5', 'Service: 5', 'Atmosphere: 5']}
# Processing review 8...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Place is straight gas
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 8 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUNGdHFubDBRRRAB', 'caption': 'Place is straight gas', 'relative_date': '5 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 835831), 'rating': 5.0, 'username': 'Nikhilesh Belulkar', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/105801928808379129591/reviews?hl=en', 'r_additional': ['Price per person $30–50', 'Food: 5', 'Service: 5', 'Atmosphere: 5']}
# Processing review 9...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Amazing middle eastern food, Ben was a great server as well.
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 9 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNGdHJHMFp3EAE', 'caption': 'Amazing middle eastern food, Ben was a great server as well.', 'relative_date': '5 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 836696), 'rating': 5.0, 'username': 'Abhimanyu Bhargava', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/107371213925992210283/reviews?hl=en', 'r_additional': ['Food: 5', 'Service: 5', 'Atmosphere: 5']}
# Processing review 10...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 10 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUNGcG9HQ2d3RRAB', 'caption': None, 'relative_date': '5 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 837651), 'rating': 5.0, 'username': 'esraa mustafa', 'n_review_user': '4', 'url_user': 'https://www.google.com/maps/contrib/112033422949629363772/reviews?hl=en', 'r_additional': ['Price per person $30–50', 'Food: 5', 'Service: 4', 'Atmosphere: 5']}
# Processing review 11...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: if you’re in to dirty, loud, unpleasant places then I highly recommend you check this spot… in one disgusting
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 11 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUQ1MzZUWGx3RRAB', 'caption': 'if you’re in to dirty, loud, unpleasant places then I highly recommend you check this spot… in one disgusting', 'relative_date': '5 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 838595), 'rating': 1.0, 'username': 'Nicky Kenickie', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/116628967267760701112/reviews?hl=en', 'r_additional': ['Service Dine in', 'Price per person $100+', 'Food: 1', 'Service: 1', 'Atmosphere: 1']}
# Processing review 12...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: I am always here! We are from brazil, very familiar with lebanese dishes. Food is very authentic and excellent. Service by Ali is always impressive. Will be back!
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 12 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUQ1bWJhQXlnRRAB', 'caption': 'I am always here! We are from brazil, very familiar with lebanese dishes. Food is very authentic and excellent. Service by Ali is always impressive. Will be back!', 'relative_date': '6 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 839442), 'rating': 5.0, 'username': 'Ana Lúcia Bizigatto', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/104175875039041926328/reviews?hl=en', 'r_additional': ['Food: 5', 'Service: 5', 'Atmosphere: 5']}
# Processing review 13...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Pictured is the famous table side shawarma & it did not disappoint. There was a very generous amount of fries along with it and can easily feed up to 4 people. Be aware that it is on the pricier side (approximately $80) but definitely worth it!  Follow our insta: @nyc.halal for more halal food reviews!!
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 13 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSURaM1l5bEJBEAE', 'caption': 'Pictured is the famous table side shawarma & it did not disappoint. There was a very generous amount of fries along with it and can easily feed up to 4 people. Be aware that it is on the pricier side (approximately $80) but definitely worth it!  Follow our insta: @nyc.halal for more halal food reviews!!', 'relative_date': '6 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 840507), 'rating': 5.0, 'username': 'NYC halal', 'n_review_user': '75', 'url_user': 'https://www.google.com/maps/contrib/117957402082366872871/reviews?hl=en', 'r_additional': ['Service Dine in', 'Meal type Dinner', 'Price per person $50–100', 'Food: 5', 'Service: 4', 'Atmosphere: 4', 'Recommended dishes Tabletop Chicken Shawarma, Fries']}
# Processing review 14...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: The food was out of this world and the service was great. It was our in-law’s anniversary and Rachid brought out a special dessert along with firework to make the celebration special! Highly recommend!
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 14 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUQ1c2ZXa0hREAE', 'caption': 'The food was out of this world and the service was great. It was our in-law’s anniversary and Rachid brought out a special dessert along with firework to make the celebration special! Highly recommend!', 'relative_date': 'a week ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 841123), 'rating': 5.0, 'username': 'Tess Bliven', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/105896485618304937649/reviews?hl=en', 'r_additional': []}
# Processing review 15...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Love this East Village spot. Big fan of the uptown location as well. Super cozy and amazing food. Would absolutely recommend to a friend!
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 15 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUQ1X3RySWlRRRAB', 'caption': 'Love this East Village spot. Big fan of the uptown location as well. Super cozy and amazing food. Would absolutely recommend to a friend!', 'relative_date': 'a week ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 842029), 'rating': 5.0, 'username': 'Aidan Bradley', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/111397950012984264487/reviews?hl=en', 'r_additional': ['Service Dine in', 'Meal type Dinner', 'Food: 5', 'Service: 5', 'Atmosphere: 5']}
# Processing review 16...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Error parsing n_reviews: 'NoneType' object has no attribute 'text'
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 16 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUQ1cG9LX3pBRRAB', 'caption': None, 'relative_date': 'a week ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 842697), 'rating': 5.0, 'username': 'Giacomo Negrotto Cambiaso', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/105147495684023315778/reviews?hl=en', 'r_additional': []}
# Processing review 17...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Absolutely a must try restaurant! Such incredibly flavorful food! Can't go wrong with anything on the menu (but you definitely need to try the Fattet al-Battenjan and the lamb chops)!!!
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 17 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUQ1eHRXcThRRRAB', 'caption': "Absolutely a must try restaurant! Such incredibly flavorful food! Can't go wrong with anything on the menu (but you definitely need to try the Fattet al-Battenjan and the lamb chops)!!!", 'relative_date': 'a week ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 843447), 'rating': 5.0, 'username': 'Joshua Mishkin', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/107880776769102969331/reviews?hl=en', 'r_additional': ['Food: 5', 'Service: 5', 'Atmosphere: 5']}
# Processing review 18...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 18 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUQ1aHZTd2ZnEAE', 'caption': None, 'relative_date': 'a week ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 844194), 'rating': 4.0, 'username': 'Nashra bukhari (Nashra)', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/106071323367016342876/reviews?hl=en', 'r_additional': ['Service: 4', 'Atmosphere: 5']}
# Processing review 19...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: For the  Gyros lovers! My family and friends (7 people) had a blast at this place today! My friend made the reservation for 2pm for lunch .We order 1 lamb and 1 chicken gyro (whole you see in the picture  ) comes with french fries and pita! Appetizer we had hummus and so many delicious dipping , salad etc. We order a bottle of rose and the man section their beers. All together we paid with drink food and dessert included $450 And still we have  “to go” boxes 2 from leftovers !! Lovely place, family friendly.  Today I took falafel,kebab and chicken kafta. The ladies at the front, I wish every restaurant have friendly waitresses like here. After we picked up the food on the side we switched the sandwiches accidentally but they help me and fix it make a new one for us in 5min.  I saved some tahini for tomorrow too! Thank you see you soon!!
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 19 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUMyaU1YWkpBEAE', 'caption': 'For the  Gyros lovers! My family and friends (7 people) had a blast at this place today! My friend made the reservation for 2pm for lunch .We order 1 lamb and 1 chicken gyro (whole you see in the picture  ) comes with french fries and pita! Appetizer we had hummus and so many delicious dipping , salad etc. We order a bottle of rose and the man section their beers. All together we paid with drink food and dessert included $450 And still we have  “to go” boxes 2 from leftovers !! Lovely place, family friendly.  Today I took falafel,kebab and chicken kafta. The ladies at the front, I wish every restaurant have friendly waitresses like here. After we picked up the food on the side we switched the sandwiches accidentally but they help me and fix it make a new one for us in 5min.  I saved some tahini for tomorrow too! Thank you see you soon!!', 'relative_date': 'a week ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 12, 844932), 'rating': 5.0, 'username': 'Brigitta Danyi', 'n_review_user': '260', 'url_user': 'https://www.google.com/maps/contrib/104342791402892226165/reviews?hl=en', 'r_additional': ['Food: 5', 'Service: 5', 'Atmosphere: 5']}
# Total reviews fetched: 20
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# The current page count is 1
# Renewing Tor IP...
# IP with Tor: 192.42.116.212
# Warning: Tor IP did not change after renewal.
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJy-o_mXf2wokRP0k0eKgTi_Q
# Attempting to sort reviews...
# Starting sort_by
# Attempting to navigate to URL...
# URL navigation successful.
# Starting __scroll
# Successfully scrolled
# Starting __expand_reviews
# Successfully expanded reviews.
# Attempting to click sorting button...
# Sorting button clicked successfully.
# Attempting to select sorting option index 1...
# Sorting option selected successfully.
# Waiting for reviews to load after sorting...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJy-o_mXf2wokRP0k0eKgTi_Q...
# [Scraping from review 0]
# Starting get_reviews
# Attempting to scroll to load reviews from offset: 0
# Starting scroll_reviews
# Successfully scrolled in scroll_reviews
# Attempting to expand review text...
# starting __expand_reviews_text
# starting to click more button
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Parsing expanded reviews...
# Processing review 0...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: The plantains were made on the spot in a rush but were not fully cooked, just cooked on the outside still pinkish inside. There was barely any meat on the baked chicken. Honestly I haven’t ate here in years and since Grinis and Polanco were closed I settled for this spot but halfway through my meal, I was reminded why I do not eat from here. Also they only take cash or Apple Pay where you have to scan a QR code or you can order on an app while you’re standing at the register. I will not be going back here.
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 0 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUNGcGY3VndRRRAB', 'caption': 'The plantains were made on the spot in a rush but were not fully cooked, just cooked on the outside still pinkish inside. There was barely any meat on the baked chicken. Honestly I haven’t ate here in years and since Grinis and Polanco were closed I settled for this spot but halfway through my meal, I was reminded why I do not eat from here. Also they only take cash or Apple Pay where you have to scan a QR code or you can order on an app while you’re standing at the register. I will not be going back here.', 'relative_date': '3 days ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 821896), 'rating': 3.0, 'username': 'Six Seven Entertainment', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/106895119246751570579/reviews?hl=en', 'r_additional': ['Service Take out', 'Price per person $10–20', 'Food: 1', 'Service: 4']}
# Processing review 1...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: It was my first time at this restaurant, and will never return. A lady who appeared to be mid 20’s or 30’s decided to take a Spanish officer’s order, and ignored myself and another Black woman as if we weren’t standing in line for a while.  As I spoke up about the issue, the ignorant lady proceeded to state “Fight for your rights” to be facetious. However, the other older ladies were respectful and considerate about the issue. It’s always one bad apple to spoil the experience.
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 1 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUQtaWN1STBBRRAB', 'caption': 'It was my first time at this restaurant, and will never return. A lady who appeared to be mid 20’s or 30’s decided to take a Spanish officer’s order, and ignored myself and another Black woman as if we weren’t standing in line for a while.  As I spoke up about the issue, the ignorant lady proceeded to state “Fight for your rights” to be facetious. However, the other older ladies were respectful and considerate about the issue. It’s always one bad apple to spoil the experience.', 'relative_date': '2 weeks ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 826399), 'rating': 1.0, 'username': 'S W', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/114360672051934541456/reviews?hl=en', 'r_additional': []}
# Processing review 2...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: I went there to get breakfast, at exactly 8am I got the mangu, cheese, and salami I got home and took my first bite and the mangu was cold, with no taste just straight nasty!! Not to mention the the price went up, but the portion is the same
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 2 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNaNWJpaUZBEAE', 'caption': 'I went there to get breakfast, at exactly 8am I got the mangu, cheese, and salami I got home and took my first bite and the mangu was cold, with no taste just straight nasty!! Not to mention the the price went up, but the portion is the same', 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 828070), 'rating': 1.0, 'username': 'Delicia Singh', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/106436491133413969730/reviews?hl=en', 'r_additional': ['Service Take out', 'Meal type Breakfast', 'Price per person $1–10', 'Food: 1', 'Service: 3', 'Atmosphere: 3']}
# Processing review 3...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Ordered online thru door dash and they sent the wrong items as well as undercooked meat. I politely asked for the sauce and they didn’t provide it either. WILL NEVER SUPPORT AGAIN! Then when I called to complain the person answered English ready to take the order and soon as I stated my issue they said no English ! Horrible service they only look after there own people
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 3 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNac3JpM013EAE', 'caption': 'Ordered online thru door dash and they sent the wrong items as well as undercooked meat. I politely asked for the sauce and they didn’t provide it either. WILL NEVER SUPPORT AGAIN! Then when I called to complain the person answered English ready to take the order and soon as I stated my issue they said no English ! Horrible service they only look after there own people', 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 829184), 'rating': 1.0, 'username': 'Ashley White', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/116047195312391498797/reviews?hl=en', 'r_additional': ['Food: 1', 'Service: 1', 'Atmosphere: 1']}
# Processing review 4...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 4 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSURwNTVhU3NBRRAB', 'caption': None, 'relative_date': '2 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 838224), 'rating': 3.0, 'username': 'Bellman Rodriguez Quiroga', 'n_review_user': '63', 'url_user': 'https://www.google.com/maps/contrib/114788571013644944394/reviews?hl=en', 'r_additional': ['Meal type Lunch', 'Price per person $10–20', 'Food: 4', 'Service: 5', 'Atmosphere: 3']}
# Processing review 5...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 5 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSURwdXVHemRREAE', 'caption': None, 'relative_date': '2 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 867095), 'rating': 5.0, 'username': 'Nelson Penalver', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/113261608905955515815/reviews?hl=en', 'r_additional': ['Meal type Other', 'Price per person $1–10', 'Food: 5', 'Service: 5', 'Atmosphere: 5']}
# Processing review 6...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: There spaghetti is sour,spoiled ,salty and possibly could have made me sick if I would have ate more then I tasted.That’s the worst food experience I ever tasted.
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 6 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSURwbk5iYXpnRRAB', 'caption': 'There spaghetti is sour,spoiled ,salty and possibly could have made me sick if I would have ate more then I tasted.That’s the worst food experience I ever tasted.', 'relative_date': '2 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 868301), 'rating': 1.0, 'username': 'Vanessa Theophile', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/115670744153928161336/reviews?hl=en', 'r_additional': ['Service Delivery', 'Meal type Dinner', 'Price per person $10–20', 'Food: 1']}
# Processing review 7...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 7 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUNwNF8zYzlBRRAB', 'caption': None, 'relative_date': '2 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 870267), 'rating': 4.0, 'username': 'Inez Nixon', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/107054075448085376025/reviews?hl=en', 'r_additional': []}
# Processing review 8...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: WE ALL ABOUT A’s G MONEY love this place and the vibes plus they got an A
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 8 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSURKdUlIX3d3RRAB', 'caption': 'WE ALL ABOUT A’s G MONEY love this place and the vibes plus they got an A', 'relative_date': '3 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 872734), 'rating': 5.0, 'username': 'jerry arias', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/117512636190080382244/reviews?hl=en', 'r_additional': ['Service Dine in', 'Meal type Dinner', 'Price per person $10–20', 'Food: 5', 'Service: 5', 'Atmosphere: 5']}
# Processing review 9...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 9 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNKbjlmdlVnEAE', 'caption': None, 'relative_date': '3 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 874375), 'rating': 4.0, 'username': 'tiffany reid', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/106007586216160611117/reviews?hl=en', 'r_additional': []}
# Processing review 10...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 10 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNKbmV1cUFREAE', 'caption': None, 'relative_date': '3 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 877570), 'rating': 4.0, 'username': 'David Peters', 'n_review_user': '12', 'url_user': 'https://www.google.com/maps/contrib/108182386080898743167/reviews?hl=en', 'r_additional': ['Service: 5', 'Atmosphere: 5']}
# Processing review 11...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: I ordered boneless crispy chicken. It was too salty for my taste. The beans and rice, however, were very good and so the service
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 11 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUR4cDREQVVnEAE', 'caption': 'I ordered boneless crispy chicken. It was too salty for my taste. The beans and rice, however, were very good and so the service', 'relative_date': '4 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 880084), 'rating': 4.0, 'username': 'Unicorn Lily', 'n_review_user': '6', 'url_user': 'https://www.google.com/maps/contrib/110629802020235646092/reviews?hl=en', 'r_additional': ['Food: 4', 'Service: 5', 'Atmosphere: 4']}
# Processing review 12...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Everything was either spoiled or on the verge of rotten. I was especially mad about my potatoe salad ….. it was so sour almost got me sick. I ordered twice and two times I received my food the same
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 12 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUR4cnVqSGtnRRAB', 'caption': 'Everything was either spoiled or on the verge of rotten. I was especially mad about my potatoe salad ….. it was so sour almost got me sick. I ordered twice and two times I received my food the same', 'relative_date': '4 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 887550), 'rating': 2.0, 'username': 'Mel Perez', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/107106002262206674934/reviews?hl=en', 'r_additional': ['Service Delivery', 'Meal type Dinner', 'Price per person $30–50', 'Food: 2', 'Atmosphere: 1']}
# Processing review 13...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Food and staff are great! I will visit again!
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 13 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSURNcGJMdkJ3EAE', 'caption': 'Food and staff are great! I will visit again!', 'relative_date': '6 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 889261), 'rating': 4.0, 'username': 'Theresa Bethea', 'n_review_user': '120', 'url_user': 'https://www.google.com/maps/contrib/104292592560662492885/reviews?hl=en', 'r_additional': ['Service Take out', 'Meal type Dinner', 'Price per person $30–50', 'Food: 4', 'Service: 4', 'Atmosphere: 4', 'Recommended dishes White Rice and Black Beans in a Cup, Sweet Plantains']}
# Processing review 14...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 14 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSURSeU1iWHZBRRAB', 'caption': None, 'relative_date': '6 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 892845), 'rating': 5.0, 'username': 'Ms Classy', 'n_review_user': '77', 'url_user': 'https://www.google.com/maps/contrib/118272095134152261845/reviews?hl=en', 'r_additional': []}
# Processing review 15...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Excellent morro. The beans are the typical Dominican beans- delicious. The garlic sauce is delicious. The baked chicken was decent. The prices were good. Excellent service. Was happy to find this Dominican restaurant on this side of town. Would definitely go back.
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 15 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNSNGZTY2VnEAE', 'caption': 'Excellent morro. The beans are the typical Dominican beans- delicious. The garlic sauce is delicious. The baked chicken was decent. The prices were good. Excellent service. Was happy to find this Dominican restaurant on this side of town. Would definitely go back.', 'relative_date': '6 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 894284), 'rating': 4.0, 'username': 'yoki', 'n_review_user': '87', 'url_user': 'https://www.google.com/maps/contrib/109219585483669388392/reviews?hl=en', 'r_additional': ['Service Take out', 'Meal type Dinner', 'Price per person $1–10', 'Food: 4', 'Service: 5', 'Atmosphere: 3']}
# Processing review 16...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: There was hair in my drink. IN MY DRINK. I ordered a store made shake and there was hair in it. Also the food was bland and cold. Do not recommend.
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 16 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSURoaTRmdk5nEAE', 'caption': 'There was hair in my drink. IN MY DRINK. I ordered a store made shake and there was hair in it. Also the food was bland and cold. Do not recommend.', 'relative_date': '7 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 895290), 'rating': 1.0, 'username': 'Rachael Nicole', 'n_review_user': '1', 'url_user': 'https://www.google.com/maps/contrib/116720029490922539638/reviews?hl=en', 'r_additional': []}
# Processing review 17...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Error parsing n_reviews: 'NoneType' object has no attribute 'text'
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 17 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSURod01mMmhBRRAB', 'caption': None, 'relative_date': '8 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 897735), 'rating': 5.0, 'username': 'Carlos Colon', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/116229780004616518933/reviews?hl=en', 'r_additional': []}
# Processing review 18...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: The food was good but I received a small portion of chicken. It's mostly bones and a lot of rice. I didn't expect to pay $9 for mainly rice.
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 18 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUNobmNYOXZRRRAB', 'caption': "The food was good but I received a small portion of chicken. It's mostly bones and a lot of rice. I didn't expect to pay $9 for mainly rice.", 'relative_date': '8 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 899457), 'rating': 2.0, 'username': 'Eve Fischer', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/107582915116768107475/reviews?hl=en', 'r_additional': ['Service Take out', 'Meal type Dinner', 'Price per person $1–10']}
# Processing review 19...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Caught Food Poison 🚫
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 19 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNoNGFMTUx3EAE', 'caption': 'Caught Food Poison 🚫', 'relative_date': '8 months ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 54, 38, 900637), 'rating': 1.0, 'username': 'joanna moore', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/106377784852946707458/reviews?hl=en', 'r_additional': ['Service Dine in', 'Meal type Dinner', 'Price per person $10–20']}
# Total reviews fetched: 20
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# The current page count is 2
# Renewing Tor IP...
# IP with Tor: 192.42.116.212
# Warning: Tor IP did not change after renewal.
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJZRSTSZn2wokRTWh-QZHhFiM
# Attempting to sort reviews...
# Starting sort_by
# Attempting to navigate to URL...
# URL navigation successful.
# Starting __scroll
# Successfully scrolled
# Starting __expand_reviews
# Successfully expanded reviews.
# Attempting to click sorting button...
# Sorting button clicked successfully.
# Attempting to select sorting option index 1...
# Sorting option selected successfully.
# Waiting for reviews to load after sorting...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJZRSTSZn2wokRTWh-QZHhFiM...
# [Scraping from review 0]
# Starting get_reviews
# Attempting to scroll to load reviews from offset: 0
# Starting scroll_reviews
# Successfully scrolled in scroll_reviews
# Attempting to expand review text...
# starting __expand_reviews_text
# starting to click more button
# Successfully expanded a review.
# Successfully expanded a review.
# Successfully expanded a review.
# Parsing expanded reviews...
# Processing review 0...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Something weird is happening here with their pricing. I have paid 5 different prices for the same item over the course of a month, sometimes more, sometimes less. Don't buy things without an advertised price or you might get grifted.  Edit: They posted prices on some items since my original review, but refuse to honor the advertised prices once you get to the register and try to charge you twice as much. Scam sales tactics, go elsewhere when possible.
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 0 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSURaNmNQQmV3EAE', 'caption': "Something weird is happening here with their pricing. I have paid 5 different prices for the same item over the course of a month, sometimes more, sometimes less. Don't buy things without an advertised price or you might get grifted.  Edit: They posted prices on some items since my original review, but refuse to honor the advertised prices once you get to the register and try to charge you twice as much. Scam sales tactics, go elsewhere when possible.", 'relative_date': 'a week ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 55, 4, 93670), 'rating': 1.0, 'username': 'Mickey Jackson', 'n_review_user': '1', 'url_user': 'https://www.google.com/maps/contrib/107225153661108832652/reviews?hl=en', 'r_additional': []}
# Processing review 1...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# ...
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 10 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSURadm9hVHNBRRAB', 'caption': 'The service is good depending on who is your waiter.', 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 55, 30, 857124), 'rating': 5.0, 'username': 'Alandra Dublin', 'n_review_user': '11', 'url_user': 'https://www.google.com/maps/contrib/116215103087093949824/reviews?hl=en', 'r_additional': ['Service Dine in', 'Meal type Breakfast', 'Price per person $30–50', 'Food: 5', 'Service: 3', 'Atmosphere: 5', 'Recommended dishes French Toast Stuffed French Toast']}
# Processing review 11...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: The reception and the food itself were forcibly decent. The presentation of the food was lousy.
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 11 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSURaOXBQNjBBRRAB', 'caption': 'The reception and the food itself were forcibly decent. The presentation of the food was lousy.', 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 55, 30, 867507), 'rating': 3.0, 'username': 'Rac SEM', 'n_review_user': '141', 'url_user': 'https://www.google.com/maps/contrib/109160963108635129248/reviews?hl=en', 'r_additional': ['Service Dine in', 'Meal type Breakfast', 'Price per person $10–20', 'Food: 3', 'Service: 4', 'Atmosphere: 2', 'Parking space Plenty of parking', 'Parking options Free parking lot']}
# Processing review 12...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: I complement the young man who was cleaning the chairs and tables. He touched my heart immensely. Be kind to our servers.🙏
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 12 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSURaNnNQbkNREAE', 'caption': 'I complement the young man who was cleaning the chairs and tables. He touched my heart immensely. Be kind to our servers.🙏', 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 55, 30, 868689), 'rating': 4.0, 'username': 'Mary Williams', 'n_review_user': '12', 'url_user': 'https://www.google.com/maps/contrib/109857227861940848960/reviews?hl=en', 'r_additional': ['Food: 5', 'Service: 5', 'Atmosphere: 5']}
# Processing review 13...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Customer service has improved
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 13 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSURxdWYtZXlnRRAB', 'caption': 'Customer service has improved', 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 55, 30, 869620), 'rating': 3.0, 'username': 'M L', 'n_review_user': '270', 'url_user': 'https://www.google.com/maps/contrib/111224586059906474011/reviews?hl=en', 'r_additional': ['Service Take out', 'Meal type Lunch', 'Price per person $10–20']}
# Processing review 14...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 14 details: {'id_review': 'ChdDSUhNMG9nS0VJQ0FnSUNaeF9lR29BRRAB', 'caption': None, 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 55, 30, 872081), 'rating': 5.0, 'username': 'Sandra 44 (Sunny)', 'n_review_user': '61', 'url_user': 'https://www.google.com/maps/contrib/107329145326148191125/reviews?hl=en', 'r_additional': ['Meal type Lunch', 'Price per person $50–100', 'Food: 5', 'Service: 4', 'Atmosphere: 3', 'Recommended dishes Original Buttermilk Pancakes with Scrambled Eggs with Cheddar Cheese']}
# Processing review 15...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 15 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNaN2F1elVnEAE', 'caption': None, 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 55, 30, 872884), 'rating': 3.0, 'username': 'Kevin Norman', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/114538018346152991177/reviews?hl=en', 'r_additional': ['Service: 3', 'Atmosphere: 4']}
# Processing review 16...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Service was great, food is standard IHOP.  Not a spot I would personally suggest but I would go if someone else wanted to go
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 16 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNadWJER2J3EAE', 'caption': 'Service was great, food is standard IHOP.  Not a spot I would personally suggest but I would go if someone else wanted to go', 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 55, 30, 878852), 'rating': 4.0, 'username': 'Gav Da Man', 'n_review_user': '57', 'url_user': 'https://www.google.com/maps/contrib/105766581417982376340/reviews?hl=en', 'r_additional': ['Service Dine in', 'Meal type Brunch', 'Price per person $20–30', 'Food: 4', 'Service: 5', 'Atmosphere: 4', 'Parking space Plenty of parking']}
# Processing review 17...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: Very Friendly Staff, Very Hospitable And Fast Service.
# Successful review_text
# Successful rating
# Successful relative_date
# Error parsing n_reviews: list index out of range
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 17 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNaX3V1SEJnEAE', 'caption': 'Very Friendly Staff, Very Hospitable And Fast Service.', 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 55, 30, 881272), 'rating': 5.0, 'username': 'Danny Arrington', 'n_review_user': 0, 'url_user': 'https://www.google.com/maps/contrib/115667574231651070591/reviews?hl=en', 'r_additional': ['Service Dine in', 'Meal type Breakfast', 'Price per person $10–20', 'Food: 4', 'Service: 5', 'Atmosphere: 5', 'Recommended dishes Turkey Bacon, Hash Browns', 'Parking space Plenty of parking', 'Parking options Free parking lot', 'Wheelchair accessibility Wheelchair Accessible']}
# Processing review 18...
# Starting __parse
# Successful id_review
# Successful username
# Starting __filter_string
# Cleaning string
# Cleaned string: I like it IHOP a lot I got beacon egg and cheese on the biscuit it’s come with hashbrown on the side and Cofee just for 9$  Tables kind of not comfortable I mean not to much space around you
# Successful review_text
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 18 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNaX29QV0dREAE', 'caption': 'I like it IHOP a lot I got beacon egg and cheese on the biscuit it’s come with hashbrown on the side and Cofee just for 9$  Tables kind of not comfortable I mean not to much space around you', 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 55, 30, 882098), 'rating': 5.0, 'username': 'One Million', 'n_review_user': '425', 'url_user': 'https://www.google.com/maps/contrib/106670180153313807225/reviews?hl=en', 'r_additional': ['Food: 5', 'Service: 5', 'Atmosphere: 4']}
# Processing review 19...
# Starting __parse
# Successful id_review
# Successful username
# Error parsing review_text: 'NoneType' object has no attribute 'text'
# Successful rating
# Successful relative_date
# Successful n_reviews
# Successful user_url
# Getting additional review info
# Successful parsed additional review info
# Review 19 details: {'id_review': 'ChZDSUhNMG9nS0VJQ0FnSUNacHNTMVpnEAE', 'caption': None, 'relative_date': 'a month ago', 'retrieval_date': datetime.datetime(2023, 11, 2, 1, 55, 30, 883447), 'rating': 4.0, 'username': 'Leah Wilson', 'n_review_user': '22', 'url_user': 'https://www.google.com/maps/contrib/111155647811005087774/reviews?hl=en', 'r_additional': ['Meal type Breakfast', 'Price per person $10–20', 'Food: 4', 'Service: 5', 'Atmosphere: 4', 'Recommended dishes Original Buttermilk Pancakes with Scrambled Eggs with Cheddar Cheese', 'Parking space Plenty of parking', 'Parking options Free parking lot']}
# Total reviews fetched: 20
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# The current page count is 4
# Renewing Tor IP...
# IP with Tor: 185.220.100.255
# Warning: Tor IP did not change after renewal.
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJnZqtE2b2wokRYBe1ctzzKJU
# Attempting to sort reviews...
# Starting sort_by
# Attempting to navigate to URL...
# URL navigation successful.
# Starting __scroll
# Successfully scrolled
# Starting __expand_reviews
# ^C
# Exiting GoogleMapsScraper context.
# Exception encountered:
# Traceback (most recent call last):
#   File "/Users/jongarcia/codeup-data-science/g_maps_scraper/scraper.py", line 73, in <module>
#     error = scraper.sort_by(url, ind[args.sort_by])
#   File "/Users/jongarcia/codeup-data-science/g_maps_scraper/googlemaps.py", line 119, in sort_by
#     self.__expand_reviews()
#   File "/Users/jongarcia/codeup-data-science/g_maps_scraper/googlemaps.py", line 494, in __expand_reviews
#     time.sleep(2)
# KeyboardInterrupt
# Closing and quitting driver.
# Traceback (most recent call last):
#   File "/Users/jongarcia/codeup-data-science/g_maps_scraper/scraper.py", line 73, in <module>
#     error = scraper.sort_by(url, ind[args.sort_by])
#   File "/Users/jongarcia/codeup-data-science/g_maps_scraper/googlemaps.py", line 119, in sort_by
#     self.__expand_reviews()
#   File "/Users/jongarcia/codeup-data-science/g_maps_scraper/googlemaps.py", line 494, in __expand_reviews
#     time.sleep(2)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/util/connection.py", line 95, in create_connection
#     raise err
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 715, in urlopen
#     httplib_response = self._make_request(
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 416, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 244, in request
#     super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#   File "/usr/local/anaconda3/lib/python3.10/http/client.py", line 1283, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/usr/local/anaconda3/lib/python3.10/http/client.py", line 1329, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/usr/local/anaconda3/lib/python3.10/http/client.py", line 1278, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/usr/local/anaconda3/lib/python3.10/http/client.py", line 1038, in _send_output
#     self.send(msg)
#   File "/usr/local/anaconda3/lib/python3.10/http/client.py", line 976, in send
#     self.connect()
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 205, in connect
#     conn = self._new_conn()
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7f86bf372a70>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jongarcia/codeup-data-science/g_maps_scraper/scraper.py", line 47, in <module>
#     with GoogleMapsScraper(debug=args.debug) as scraper:
#   File "/Users/jongarcia/codeup-data-science/g_maps_scraper/googlemaps.py", line 99, in __exit__
#     self.driver.close()
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py", line 455, in close
#     self.execute(Command.CLOSE)
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py", line 342, in execute
#     response = self.command_executor.execute(driver_command, params)
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py", line 297, in execute
#     return self._request(command_info[0], url, body=data)
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py", line 318, in _request
#     response = self._conn.request(method, url, body=body, headers=headers)
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/request.py", line 77, in request
#     return self.request_encode_url(
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/request.py", line 99, in request_encode_url
#     return self.urlopen(method, url, **extra_kw)
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/poolmanager.py", line 376, in urlopen
#     response = conn.urlopen(method, u.request_uri, **kw)
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 827, in urlopen
#     return self.urlopen(
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 827, in urlopen
#     return self.urlopen(
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 827, in urlopen
#     return self.urlopen(
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 799, in urlopen
#     retries = retries.increment(
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=64639): Max retries exceeded with url: /session/73400f93899d528284ed3bfcac68b87e/window (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f86bf372a70>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
# !python scraper.py --N 200 --i places_scrape_rdy.csv --debug
# Out:
# Scraper initialized successfully.
# IP masking successful: Your IP address is being masked by Tor.
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJxdtcy1BawokRlmnITiRDcU4
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJxdtcy1BawokRlmnITiRDcU4...
# [Scraping from review 0]
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 20]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 30]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 40]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 50]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 60]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 70]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 80]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 90]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 100]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 110]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 120]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 130]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 140]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 150]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 160]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 170]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 180]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 190]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# The current page count is 1
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJlwQhLilbwokR24kEIHvpD_g
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJlwQhLilbwokR24kEIHvpD_g...
# [Scraping from review 0]
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 20]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 30]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 40]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 50]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 60]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 70]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 80]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 90]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 100]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 110]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 120]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 130]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 140]
# Number of reviews fetched: 2
# Review written to CSV
# Review written to CSV
# [Scraping from review 142]
# Number of reviews fetched: 0
# No more reviews to fetch. Breaking out of the loop.
# The current page count is 2
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJiyqjDgVcwokRRGqRBulo9kQ
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJiyqjDgVcwokRRGqRBulo9kQ...
# [Scraping from review 0]
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 20]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 30]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 40]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 50]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 60]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 70]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 80]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 90]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 100]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 110]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 120]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 130]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 140]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 150]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 160]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 170]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 180]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 190]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# The current page count is 3
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJ3S36prhbwokRSYJ7cSFonf8
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJ3S36prhbwokRSYJ7cSFonf8...
# [Scraping from review 0]
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 20]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 30]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 40]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 50]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 60]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 70]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 80]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 90]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 100]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 110]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 120]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 130]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 140]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 150]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 160]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 170]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 180]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 190]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# The current page count is 4
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJpwu_dB1cwokRB_7Vq9WZDh0
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJpwu_dB1cwokRB_7Vq9WZDh0...
# [Scraping from review 0]
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 20]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 30]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 40]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 50]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 60]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 70]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 80]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 90]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 100]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 110]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 120]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 130]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 140]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 150]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 160]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 170]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 180]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 190]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# The current page count is 5
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJ9QSMMZxbwokRmYUpKN-gzRk
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJ9QSMMZxbwokRmYUpKN-gzRk...
# [Scraping from review 0]
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 20]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 30]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 40]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 50]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 60]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 70]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 80]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 90]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 100]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 110]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 120]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 130]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 140]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 150]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 160]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 170]
# Number of reviews fetched: 1
# Review written to CSV
# [Scraping from review 171]
# Number of reviews fetched: 0
# No more reviews to fetch. Breaking out of the loop.
# The current page count is 6
# Processing URL: https://www.google.com/maps/place/?q=place_id:EiYyMXN0IEF2ZSwgRWFzdCBFbG1odXJzdCwgTlkgMTEzNzAsIFVTQSIuKiwKFAoSCbVRMo1kX8KJEV453OfGHHB_EhQKEgmpWmpqdV_CiRGbNiBiO3IC0g
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:EiYyMXN0IEF2ZSwgRWFzdCBFbG1odXJzdCwgTlkgMTEzNzAsIFVTQSIuKiwKFAoSCbVRMo1kX8KJEV453OfGHHB_EhQKEgmpWmpqdV_CiRGbNiBiO3IC0g
# The current page count is 7
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJo6B0_YBbwokRdIcg84XUGZs
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJo6B0_YBbwokRdIcg84XUGZs...
# [Scraping from review 0]
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 20]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 30]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 40]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 50]
# Number of reviews fetched: 3
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 53]
# Number of reviews fetched: 0
# No more reviews to fetch. Breaking out of the loop.
# The current page count is 8
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJZchNI6xFwokRpdYtwIm6k-Q
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJZchNI6xFwokRpdYtwIm6k-Q...
# [Scraping from review 0]
# Number of reviews fetched: 12
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 12]
# Number of reviews fetched: 0
# No more reviews to fetch. Breaking out of the loop.
# The current page count is 9
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJQ9okzpf0wokR0qe8TNl3oL4
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJQ9okzpf0wokR0qe8TNl3oL4...
# [Scraping from review 0]
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 20]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 30]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 40]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 50]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 60]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 70]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 80]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 90]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 100]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 110]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 120]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 130]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 140]
# Number of reviews fetched: 0
# No more reviews to fetch. Breaking out of the loop.
# The current page count is 10
# Renewing Tor IP...
# DEBUG:stem:GETCONF __owningcontrollerprocess (runtime: 0.0015)
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "read of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# Tor IP successfully renewed.
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJq8u2FxlcwokRAAw1gBCPzcE
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJq8u2FxlcwokRAAw1gBCPzcE...
# [Scraping from review 0]
# Number of reviews fetched: 20
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 20]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 30]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 40]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 50]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 60]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 70]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 80]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 90]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 100]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 110]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 120]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 130]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 140]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 150]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 160]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 170]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 180]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 190]
# Number of reviews fetched: 10
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# ...
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJV_yFgnRFwokRczFApNqPk38
# The current page count is 57
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJMyP05vpgwokR53d5e0AdtGo
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJMyP05vpgwokR53d5e0AdtGo
# The current page count is 58
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJn-SQE_xgwokROTtYD_ClYJY
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJn-SQE_xgwokROTtYD_ClYJY
# The current page count is 59
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJWSTUrQ5cwokRq8QDWX6Hq2A
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJWSTUrQ5cwokRq8QDWX6Hq2A
# The current page count is 60
# Renewing Tor IP...
# DEBUG:stem:GETCONF __owningcontrollerprocess (runtime: 0.0012)
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "read of closed file"
# Tor IP successfully renewed.
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJ82dpUrnzwokRI2qNB26-RBU
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJ82dpUrnzwokRI2qNB26-RBU
# The current page count is 61
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJfXfu_CZawokRsynindnEfPY
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJfXfu_CZawokRsynindnEfPY
# The current page count is 62
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJ-ypqOwP0wokR0XwRtjhoxAk
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJ-ypqOwP0wokR0XwRtjhoxAk
# The current page count is 63
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJ_____4BZwokRwuOBV5usHR4
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJ_____4BZwokRwuOBV5usHR4
# The current page count is 64
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJqYgZ3YRYwokRrj5Tf7MWmOI
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJqYgZ3YRYwokRrj5Tf7MWmOI
# The current page count is 65
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJ82gDNHZZwokRBf77DPjfSDc
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJ82gDNHZZwokRBf77DPjfSDc
# The current page count is 66
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJyZdtZ4xgwokRIYBZOEstiBg
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJyZdtZ4xgwokRIYBZOEstiBg
# The current page count is 67
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJ3clrtL3zwokRhjAz6huLhlU
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJ3clrtL3zwokRhjAz6huLhlU
# The current page count is 68
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJfZI3q4pbwokR4kvIkKrl5SA
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJfZI3q4pbwokR4kvIkKrl5SA
# The current page count is 69
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJEw37uV1ZwokRWHsTZx1hg1A
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJEw37uV1ZwokRWHsTZx1hg1A
# The current page count is 70
# Renewing Tor IP...
# DEBUG:stem:GETCONF __owningcontrollerprocess (runtime: 0.0005)
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "[Errno 9] Bad file descriptor"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# INFO:stem:Error while receiving a control message (SocketClosed): received exception "peek of closed file"
# Tor IP successfully renewed.
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJc5hccd9FwokRtKRz1DGLWSM
# Attempting to sort reviews...
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# WARNING:googlemaps-scraper:Failed to click sorting button
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJc5hccd9FwokRtKRz1DGLWSM
# The current page count is 71
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJ9_E9rCX2wokRA-KHf2-flk8
# Attempting to sort reviews...
# Traceback (most recent call last):
#   File "/Users/jongarcia/codeup-data-science/g_maps_scraper/scraper.py", line 73, in <module>
#     error = scraper.sort_by(url, ind[args.sort_by])
#   File "/Users/jongarcia/codeup-data-science/g_maps_scraper/googlemaps.py", line 108, in sort_by
#     self.driver.get(url)
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py", line 353, in get
#     self.execute(Command.GET, {"url": url})
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py", line 344, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/anaconda3/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py", line 229, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.TimeoutException: Message: timeout: Timed out receiving message from renderer: 299.323
#   (Session info: chrome=120.0.6099.5)
# Stacktrace:
# 0   chromedriver                        0x0000000107bb5498 chromedriver + 4793496
# 1   chromedriver                        0x0000000107baca23 chromedriver + 4758051
# 2   chromedriver                        0x00000001077868cd chromedriver + 407757
# 3   chromedriver                        0x000000010776c306 chromedriver + 299782
# 4   chromedriver                        0x000000010776c1cd chromedriver + 299469
# 5   chromedriver                        0x000000010776aa3a chromedriver + 293434
# 6   chromedriver                        0x000000010776b0f9 chromedriver + 295161
# 7   chromedriver                        0x000000010777bcdc chromedriver + 363740
# 8   chromedriver                        0x0000000107794098 chromedriver + 463000
# 9   chromedriver                        0x000000010779a0cb chromedriver + 487627
# 10  chromedriver                        0x000000010776b940 chromedriver + 297280
# 11  chromedriver                        0x0000000107793ed5 chromedriver + 462549
# 12  chromedriver                        0x0000000107818bc7 chromedriver + 1006535
# 13  chromedriver                        0x00000001077fcab3 chromedriver + 891571
# 14  chromedriver                        0x00000001077c7173 chromedriver + 672115
# 15  chromedriver                        0x00000001077c834e chromedriver + 676686
# 16  chromedriver                        0x0000000107b76415 chromedriver + 4535317
# 17  chromedriver                        0x0000000107b7b647 chromedriver + 4556359
# 18  chromedriver                        0x0000000107b5b441 chromedriver + 4424769
# 19  chromedriver                        0x0000000107b7c3ad chromedriver + 4559789
# 20  chromedriver                        0x0000000107b4c8dc chromedriver + 4364508
# 21  chromedriver                        0x0000000107b9b818 chromedriver + 4687896
# 22  chromedriver                        0x0000000107b9b9ce chromedriver + 4688334
# 23  chromedriver                        0x0000000107bac65e chromedriver + 4757086
# 24  libsystem_pthread.dylib             0x00007ff80e2151d3 _pthread_start + 125
# 25  libsystem_pthread.dylib             0x00007ff80e210bd3 thread_start + 15

# %%
# !python scraper.py --N 50 --i urls_1.txt
