# %%
import pandas as pd

# %%
r_1k = pd.read_csv('reviews_1k.csv')
r_2k = pd.read_csv('reviews_2k.csv')

# %%
r_1k.head(2)
# Out:
#          id                             id_review  \
# 0  50138517   ChZDSUhNMG9nS0VJQ0FnSUNGcGF5bFV3EAE
# 1  50138517  ChdDSUhNMG9nS0VJQ0FnSUQ1MGVhUHRnRRAB
#
#                                              caption relative_date  \
# 0                                                NaN    5 days ago
# 1  Broth salty, cloudy. Summer rolls old. Short o...    a week ago
#
#                retrieval_date  rating           username n_review_user  \
# 0  2023-11-04 04:31:32.813385     5.0  Christopher Croft            40
# 1  2023-11-04 04:31:32.814883     2.0               D HH             1
#
#                                             url_user  \
# 0  https://www.google.com/maps/contrib/1158098693...
# 1  https://www.google.com/maps/contrib/1047236894...
#
#                                         r_additional
# 0                    ['Service: 5', 'Atmosphere: 5']
# 1  ['Service Dine in', 'Meal type Lunch', 'Price ...

# %%
r_ = pd.read_csv('reviews_.csv')

# %%
r_.head()
# Out:
#          id                             id_review  \
# 0  41375676   ChZDSUhNMG9nS0VJQ0FnSUNGMDhHSkVnEAE
# 1  41375676  ChdDSUhNMG9nS0VJQ0FnSUNGM2NhcGpnRRAB
# 2  41375676  ChdDSUhNMG9nS0VJQ0FnSUNGbmVidnRRRRAB
# 3  41375676   ChZDSUhNMG9nS0VJQ0FnSUNGNmY2Q0F3EAE
# 4  41375676   ChZDSUhNMG9nS0VJQ0FnSUNGNmZEdEVnEAE
#
#                                              caption relative_date  \
# 0                                                NaN  11 hours ago
# 1                                                NaN     a day ago
# 2                                                NaN     a day ago
# 3                                      Fabulous food    4 days ago
# 4  Overrated.  Terrible service, the fault of the...    4 days ago
#
#                retrieval_date  rating           username n_review_user  \
# 0  2023-11-02 02:44:04.226505     5.0     Eddie Trujillo             1
# 1  2023-11-02 02:44:04.227451     5.0  Mahamadou Asouman             0
# ...

# %%
scraped_reviews = pd.concat([r_1k, r_2k, r_], ignore_index=True)

# %%
len(scraped_reviews)
# Out:
# 325203

# %%
scraped_reviews.head()
# Out:
#          id                             id_review  \
# 0  50138517   ChZDSUhNMG9nS0VJQ0FnSUNGcGF5bFV3EAE
# 1  50138517  ChdDSUhNMG9nS0VJQ0FnSUQ1MGVhUHRnRRAB
# 2  50138517  ChdDSUhNMG9nS0VJQ0FnSUQ1X0xQamdBRRAB
# 3  50138517  ChdDSUhNMG9nS0VJQ0FnSUM1ak1pTTd3RRAB
# 4  50138517   ChZDSUhNMG9nS0VJQ0FnSUM1cEl1RllREAE
#
#                                              caption relative_date  \
# 0                                                NaN    5 days ago
# 1  Broth salty, cloudy. Summer rolls old. Short o...    a week ago
# 2  Had the brisket and flank pho, the broth and n...   2 weeks ago
# 3                                                NaN   3 weeks ago
# 4  I was waiting in front of the counter for at l...   3 weeks ago
#
#                retrieval_date  rating           username n_review_user  \
# 0  2023-11-04 04:31:32.813385     5.0  Christopher Croft            40
# 1  2023-11-04 04:31:32.814883     2.0               D HH             1
# ...

# %%
scraped_reviews = scraped_reviews.drop_duplicates()

# %%
len(scraped_reviews)
# Out:
# 20037

# %%
scraped_reviews.reset_index(drop=True, inplace=True)

# %%
scraped_reviews.to_csv('reviews_.csv', index=False)

# %%
scraped_reviews_read = pd.read_csv('scraped_reviews.csv')

# %%
scraped_reviews_read.head(2)
# Out:
#          id                             id_review  \
# 0  50138517   ChZDSUhNMG9nS0VJQ0FnSUNGcGF5bFV3EAE
# 1  50138517  ChdDSUhNMG9nS0VJQ0FnSUQ1MGVhUHRnRRAB
#
#                                              caption relative_date  \
# 0                                                NaN    5 days ago
# 1  Broth salty, cloudy. Summer rolls old. Short o...    a week ago
#
#                retrieval_date  rating           username n_review_user  \
# 0  2023-11-04 04:31:32.813385     5.0  Christopher Croft            40
# 1  2023-11-04 04:31:32.814883     2.0               D HH             1
#
#                                             url_user  \
# 0  https://www.google.com/maps/contrib/1158098693...
# 1  https://www.google.com/maps/contrib/1047236894...
#
#                                         r_additional
# 0                    ['Service: 5', 'Atmosphere: 5']
# 1  ['Service Dine in', 'Meal type Lunch', 'Price ...
