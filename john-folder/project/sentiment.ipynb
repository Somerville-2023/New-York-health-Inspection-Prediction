# %%
import pandas as pd 
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

def vader_sentiment_analysis(df):
    '''
    Takes in a dataframe with 2 columns named:
    camis, reviews_sw
    reviews_sw = block of text minus stop words
    returns a dataframe of five collums:
    camis, neg, neu, pos, compound
    '''
    sia = SentimentIntensityAnalyzer()
    vader_results = {}
    for i, row in df.iterrows():
        review = row['reviews_sw']
        index_id = i
        vader_results[index_id] = sia.polarity_scores(review)
        # Transposes vader results so that data is the long way.
        vader_results_df = pd.DataFrame(vader_results).T
    return vader_results_df
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jongarcia/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
ny = pd.read_csv('ny_sentiment.csv')

# %%
ny.head()
# Out:
#       camis                 dba       boro       phone inspection_date  \
# 0  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2021-08-04
# 1  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2022-05-18
# 2  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2023-05-17
# 3  40365904        MEE SUM CAFE  Manhattan  2123495260      2021-10-13
# 4  40365904        MEE SUM CAFE  Manhattan  2123495260      2021-11-24
#
#     latitude  longitude cuisine_description            action  score grade  \
# 0  40.734908 -74.002973      Latin American  Violations cited     27     B
# 1  40.734908 -74.002973      Latin American  Violations cited     19     B
# 2  40.734908 -74.002973      Latin American  Violations cited     12     A
# 3  40.714861 -73.998200          Coffee/Tea  Violations cited     67     C
# 4  40.714861 -73.998200          Coffee/Tea  Violations cited     24     B
#
#               full_address                               violation_code  \
# 0  62 CHARLES STREET 10014                          10B 04L 02H 04H 08A
# 1  62 CHARLES STREET 10014                              04L 08C 06C 08A
# 2  62 CHARLES STREET 10014                                  10B 04L 08A
# 3     26 PELL STREET 10013  02G 04A 08A 06C 02B 04N 05D 10B 10F 09C 06F
# 4     26 PELL STREET 10013                          10F 02G 02B 06C 10B
#
#                                violation_description last_inspection_date  \
# 0  Plumbing not properly installed or maintained;...           2020-08-04
# 1  Evidence of mice or live mice present in facil...           2021-08-04
# 2  Anti-siphonage or back-flow prevention device ...           2022-05-18
# 3  Cold food item held above 41º F (smoked fish a...           2020-10-13
# 4  Non-food contact surface improperly constructe...           2021-10-13
#
#                                 concatenated_reviews  \
# 0    Horrible food and slow service. Seafood in p...
# 1      Superb! I haven’t had good paella since mo...
# 2  Gem in the océano of nyc. Spanish dishes and o...
# 3    Very authentic place. To the point that I ne...
# 4  Really great classic Chinese comfort food. Gre...
#
#                                           reviews_sw
# 0  Horrible food slow service. Seafood paella tas...
# 1  Superb! I haven’t good paella since moving bac...
# 2  Gem océano nyc. Spanish dishes old school span...
# 3  Very authentic place. To point I needed lots h...
# 4  Really great classic Chinese comfort food. Gre...

# %%
ny.concatenated_reviews.isna().sum()
# Out:
# 0

# %%
ny_head = ny.head()

# %%
ny.shape
# Out:
# (2594, 21)

# %%
ny_sentiment = vader_sentiment_analysis(ny)
ny_sentiment.head()
# Out:
#      neg    neu    pos  compound
# 0  0.084  0.673  0.244    0.9975
# 1  0.041  0.630  0.330    0.9998
# 2  0.055  0.581  0.365    1.0000
# 3  0.060  0.688  0.252    0.7717
# 4  0.000  0.537  0.463    0.9468

# %%
ny = pd.read_csv('ny_reviews_processed.csv')
ny.head()
# Out:
#       camis                 dba       boro       phone inspection_date  \
# 0  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2021-08-04
# 1  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2022-05-18
# 2  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2023-05-17
# 3  40365904        MEE SUM CAFE  Manhattan  2123495260      2021-10-13
# 4  40365904        MEE SUM CAFE  Manhattan  2123495260      2021-11-24
#
#     latitude  longitude cuisine_description            action  score  ...  \
# 0  40.734908 -74.002973      Latin American  Violations cited     27  ...
# 1  40.734908 -74.002973      Latin American  Violations cited     19  ...
# 2  40.734908 -74.002973      Latin American  Violations cited     12  ...
# 3  40.714861 -73.998200          Coffee/Tea  Violations cited     67  ...
# 4  40.714861 -73.998200          Coffee/Tea  Violations cited     24  ...
#
#               full_address                               violation_code  \
# 0  62 CHARLES STREET 10014                          10B 04L 02H 04H 08A
# 1  62 CHARLES STREET 10014                              04L 08C 06C 08A
# 2  62 CHARLES STREET 10014                                  10B 04L 08A
# 3     26 PELL STREET 10013  02G 04A 08A 06C 02B 04N 05D 10B 10F 09C 06F
# 4     26 PELL STREET 10013                          10F 02G 02B 06C 10B
#
#                                violation_description last_inspection_date  \
# 0  Plumbing not properly installed or maintained;...           2020-08-04
# 1  Evidence of mice or live mice present in facil...           2021-08-04
# 2  Anti-siphonage or back-flow prevention device ...           2022-05-18
# 3  Cold food item held above 41º F (smoked fish a...           2020-10-13
# 4  Non-food contact surface improperly constructe...           2021-10-13
#
#   avg_service  avg_atmosphere  avg_food  avg_price  \
# 0    5.000000        5.000000       5.0  60.612245
# 1    5.000000        5.000000       5.0  60.612245
# 2    5.000000        5.000000       5.0  60.612245
# 3    4.333333        4.333333       4.5  17.692308
# 4    4.333333        4.333333       4.5  17.692308
#
#                                           reviews_sw  \
# 0  Horrible food slow service. Seafood paella tas...
# 1  Superb! I haven’t good paella since moving bac...
# 2  Gem océano nyc. Spanish dishes old school span...
# 3  Very authentic place. To point I needed lots h...
# 4  Really great classic Chinese comfort food. Gre...
#
#                                              reviews
# 0  horrible food slow service seafood paella tast...
# 1  superb havent good paella since moving back ny...
# 2  gem ocano nyc spanish dish old school spanish ...
# 3  authentic place point needed lot help managed ...
# 4  really great classic chinese comfort food grea...
#
# [5 rows x 21 columns]

# %%
ny.shape
# Out:
# (2594, 21)

# %%
ny_reviews_sentiment = pd.concat([ny, ny_sentiment], axis=1)
ny_reviews_sentiment.head()
# Out:
#       camis                 dba       boro       phone inspection_date  \
# 0  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2021-08-04
# 1  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2022-05-18
# 2  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2023-05-17
# 3  40365904        MEE SUM CAFE  Manhattan  2123495260      2021-10-13
# 4  40365904        MEE SUM CAFE  Manhattan  2123495260      2021-11-24
#
#     latitude  longitude cuisine_description            action  score  ...  \
# 0  40.734908 -74.002973      Latin American  Violations cited     27  ...
# 1  40.734908 -74.002973      Latin American  Violations cited     19  ...
# 2  40.734908 -74.002973      Latin American  Violations cited     12  ...
# 3  40.714861 -73.998200          Coffee/Tea  Violations cited     67  ...
# 4  40.714861 -73.998200          Coffee/Tea  Violations cited     24  ...
#
#   avg_service avg_atmosphere avg_food  avg_price  \
# 0    5.000000       5.000000      5.0  60.612245
# 1    5.000000       5.000000      5.0  60.612245
# 2    5.000000       5.000000      5.0  60.612245
# 3    4.333333       4.333333      4.5  17.692308
# 4    4.333333       4.333333      4.5  17.692308
#
#                                           reviews_sw  \
# 0  Horrible food slow service. Seafood paella tas...
# 1  Superb! I haven’t good paella since moving bac...
# 2  Gem océano nyc. Spanish dishes old school span...
# 3  Very authentic place. To point I needed lots h...
# 4  Really great classic Chinese comfort food. Gre...
#
#                                              reviews    neg    neu    pos  \
# 0  horrible food slow service seafood paella tast...  0.084  0.673  0.244
# 1  superb havent good paella since moving back ny...  0.041  0.630  0.330
# 2  gem ocano nyc spanish dish old school spanish ...  0.055  0.581  0.365
# 3  authentic place point needed lot help managed ...  0.060  0.688  0.252
# 4  really great classic chinese comfort food grea...  0.000  0.537  0.463
#
#   compound
# 0   0.9975
# 1   0.9998
# 2   1.0000
# 3   0.7717
# 4   0.9468
#
# [5 rows x 25 columns]

# %%
ny_reviews_sentiment.shape
# Out:
# (2594, 25)

# %%
ny_reviews_sentiment.to_csv('ny_reviews_sentiment_ratings.csv', index=False)

# %%
ny_reviews_sentiment = pd.read_csv('ny_reviews_sentiment.csv')
ny_reviews_sentiment.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jongarcia/codeup-data-science/New-York-health-Inspection-Prediction/john-folder/project/sentiment.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/New-York-health-Inspection-Prediction/john-folder/project/sentiment.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> ny_reviews_sentiment = pd.read_csv('ny_reviews_sentiment.csv')
#       <a href='vscode-notebook-cell:/Users/jongarcia/codeup-data-science/New-York-health-Inspection-Prediction/john-folder/project/sentiment.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> ny_reviews_sentiment.head()
#
# NameError: name 'pd' is not defined
