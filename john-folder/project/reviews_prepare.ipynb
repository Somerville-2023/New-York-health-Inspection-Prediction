# %%
import pandas as pd
import reviews_prepare as p

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ny.shape
# Out:
# (4098, 17)

# %%
ny = pd.read_csv('ny_reviews.csv')
ny.head()
# Out:
#       camis                    dba   boro       phone inspection_date  \
# 0  30075445  MORRIS PARK BAKE SHOP  Bronx  7188924968      2021-08-10
# 1  30075445  MORRIS PARK BAKE SHOP  Bronx  7188924968      2023-01-31
# 2  30075445  MORRIS PARK BAKE SHOP  Bronx  7188924968      2023-02-03
# 3  30075445  MORRIS PARK BAKE SHOP  Bronx  7188924968      2023-08-01
# 4  30075445  MORRIS PARK BAKE SHOP  Bronx  7188924968      2023-08-22
#
#     latitude  longitude       cuisine_description            action  score  \
# 0  40.848231 -73.855972  Bakery Products/Desserts  Violations cited      5
# 1  40.848231 -73.855972  Bakery Products/Desserts            Closed     21
# 2  40.848231 -73.855972  Bakery Products/Desserts         Re-opened     13
# 3  40.848231 -73.855972  Bakery Products/Desserts  Violations cited     38
# 4  40.848231 -73.855972  Bakery Products/Desserts  Violations cited     12
#
#   grade                   full_address                   violation_code  \
# ...

# %%
ny.shape
# Out:
# (59989, 16)

# %%
ny = ny[ny.concatenated_reviews.notna()]
ny.shape
# Out:
# (4098, 16)

# %%
# ny = ny.drop(columns=['latitude', 'longitude', 'phone', 'action', 'full_address', 'violation_code', 'violation_description'])

# %%
ny.head()
# Out:
#         camis           dba       boro       phone inspection_date   latitude  \
# 155  40365904  MEE SUM CAFE  Manhattan  2123495260      2021-10-13  40.714861
# 156  40365904  MEE SUM CAFE  Manhattan  2123495260      2021-11-24  40.714861
# 157  40365904  MEE SUM CAFE  Manhattan  2123495260      2022-06-27  40.714861
# 158  40365904  MEE SUM CAFE  Manhattan  2123495260      2022-09-30  40.714861
# 159  40365904  MEE SUM CAFE  Manhattan  2123495260      2023-04-14  40.714861
#
#      longitude cuisine_description            action  score grade  \
# 155   -73.9982          Coffee/Tea  Violations cited     67     C
# 156   -73.9982          Coffee/Tea  Violations cited     24     B
# 157   -73.9982          Coffee/Tea  Violations cited     50     C
# 158   -73.9982          Coffee/Tea  Violations cited     59     C
# 159   -73.9982          Coffee/Tea  Violations cited     36     C
#
#              full_address                               violation_code  \
# ...

# %%
ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4098 entries, 155 to 59941
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   camis                  4098 non-null   int64
#  1   dba                    4098 non-null   object
#  2   boro                   4098 non-null   object
#  3   phone                  4098 non-null   int64
#  4   inspection_date        4098 non-null   object
#  5   latitude               4098 non-null   float64
#  6   longitude              4098 non-null   float64
#  7   cuisine_description    4098 non-null   object
#  8   action                 4098 non-null   object
#  9   score                  4098 non-null   int64
#  10  grade                  4098 non-null   object
#  11  full_address           4098 non-null   object
#  12  violation_code         4098 non-null   object
#  13  violation_description  4098 non-null   object
# ...

# %%
# # Apply the cleaning function to the concatenated_reviews column
# ny['cleaned_reviews'] = ny['concatenated_reviews'].apply(p.basic_clean)

# %%
# ny.head()

# %%
# ny.cleaned_reviews.iloc[0]

# %%
ny = pd.read_csv('ny_reviews_3.csv')
ny.head()
# Out:
#       camis                 dba       boro       phone inspection_date  \
# 0  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2021-08-04
# 1  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2022-05-18
# 2  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2023-05-17
# 3  40365904        MEE SUM CAFE  Manhattan  2123495260      2021-10-13
# 4  40365904        MEE SUM CAFE  Manhattan  2123495260      2021-11-24
#
#     latitude  longitude cuisine_description            action  score grade  \
# 0  40.734908 -74.002973      Latin American  Violations cited     27     B
# 1  40.734908 -74.002973      Latin American  Violations cited     19     B
# 2  40.734908 -74.002973      Latin American  Violations cited     12     A
# 3  40.714861 -73.998200          Coffee/Tea  Violations cited     67     C
# 4  40.714861 -73.998200          Coffee/Tea  Violations cited     24     B
#
#               full_address                               violation_code  \
# ...

# %%
extra_words = []
exclude_words = []

# Apply stopwords removal and text processing based on the selected method
ny['reviews_sw'] = ny['concatenated_reviews'].apply(lambda x: p.remove_stopwords(x, extra_words, exclude_words))

# %%
ny.to_csv('ny_sentiment.csv', index=False)

# %%
ny.head()
# Out:
#       camis                 dba       boro       phone inspection_date  \
# 0  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2021-08-04
# 1  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2022-05-18
# 2  40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2023-05-17
# 3  40365904        MEE SUM CAFE  Manhattan  2123495260      2021-10-13
# 4  40365904        MEE SUM CAFE  Manhattan  2123495260      2021-11-24
#
#     latitude  longitude cuisine_description            action  score grade  \
# 0  40.734908 -74.002973      Latin American  Violations cited     27     B
# 1  40.734908 -74.002973      Latin American  Violations cited     19     B
# 2  40.734908 -74.002973      Latin American  Violations cited     12     A
# 3  40.714861 -73.998200          Coffee/Tea  Violations cited     67     C
# 4  40.714861 -73.998200          Coffee/Tea  Violations cited     24     B
#
#               full_address                               violation_code  \
# ...

# %%
# Define lists for additional and exclusionary words
extra_words = []

exclude_words = []

p.preprocess_text_column(ny, extra_words=[], exclude_words=[], method='lemmatize')
# Out:
#          camis                 dba       boro       phone inspection_date  \
# 0     40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2021-08-04
# 1     40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2022-05-18
# 2     40364439  SEVILLA RESTAURANT  Manhattan  2129293189      2023-05-17
# 3     40365904        MEE SUM CAFE  Manhattan  2123495260      2021-10-13
# 4     40365904        MEE SUM CAFE  Manhattan  2123495260      2021-11-24
# ...        ...                 ...        ...         ...             ...
# 2589  50140292     TACOS POR FAVOR   Brooklyn  9176000023      2023-10-12
# 2590  50140509           MR. Q BBQ   Brooklyn  3472005298      2023-09-12
# 2591  50140822        SUSHI BY BOU  Manhattan  9175281226      2023-09-19
# 2592  50140823      TANG BY MR SUN  Manhattan  3476068152      2023-09-12
# 2593  50140852  12 CHAIRS CATERING  Manhattan  2122548640      2023-09-27
#
#        latitude  longitude cuisine_description            action  score  ...  \
# ...

# %%
ny.reviews.iloc[0]
# Out:
# 'authentic place point needed lot help managed sample go mandarin speaking friend soup good place quick low price meal old style chinese coffee shop'

# %%
ny.reset_index(drop=True, inplace=True)
ny.to_csv('ny_reviews_processed.csv', index=False)

# %%
ny.head()
# Out:
#       camis           dba       boro       phone inspection_date   latitude  \
# 0  40365904  MEE SUM CAFE  Manhattan  2123495260      2021-10-13  40.714861
# 1  40365904  MEE SUM CAFE  Manhattan  2123495260      2021-11-24  40.714861
# 2  40365904  MEE SUM CAFE  Manhattan  2123495260      2022-06-27  40.714861
# 3  40365904  MEE SUM CAFE  Manhattan  2123495260      2022-09-30  40.714861
# 4  40365904  MEE SUM CAFE  Manhattan  2123495260      2023-04-14  40.714861
#
#    longitude cuisine_description            action  score grade  \
# 0   -73.9982          Coffee/Tea  Violations cited     67     C
# 1   -73.9982          Coffee/Tea  Violations cited     24     B
# 2   -73.9982          Coffee/Tea  Violations cited     50     C
# 3   -73.9982          Coffee/Tea  Violations cited     59     C
# 4   -73.9982          Coffee/Tea  Violations cited     36     C
#
#            full_address                               violation_code  \
# ...
