# %%
import pandas as pd

# ny.to_csv('final_ny.csv')

# %%
pd.read_csv('reviews.csv')
# Out:
#           camis                publish_time  \
# 0      41375676  2023-11-01 02:44:04.226505
# 1      41375676  2023-11-01 02:44:04.227451
# 2      41375676  2023-11-01 02:44:04.227954
# 3      41375676  2023-10-29 02:44:04.228882
# 4      41375676  2023-10-29 02:44:04.229576
# ...         ...                         ...
# 61332  50107528   2023-05-24 21:33:14+00:00
# 61333  50107528   2023-07-16 04:20:30+00:00
# 61334  50107528   2023-05-09 18:27:59+00:00
# 61335  50107528   2023-03-05 21:48:09+00:00
# 61336  50107528   2023-10-23 13:20:31+00:00
#
#                                              review_text  review_rating
# 0                                                    NaN              5
# 1                                                    NaN              5
# 2                                                    NaN              5
# 3                                          Fabulous food              5
# ...

# %%
pd.read_csv('final_ny.csv', index_col=0)
# Out:
#           camis                                                dba       boro  \
# 0      41168748                                             DUNKIN      Bronx
# 1      41688142                                           TABLE 87   Brooklyn
# 2      50100336                                             SUBWAY   Brooklyn
# 3      50086686                                             GERTIE   Brooklyn
# 4      50081121                                             DUNKIN   Brooklyn
# ...         ...                                                ...        ...
# 60820  50001313                              NEW GOLDEN RESTAURANT   Brooklyn
# 60821  50064419  BURGER JOINT (INDUSTRY CITY FOOD HALL BUILDING 2)   Brooklyn
# 60822  50093964                        DOWNSTEIN DINING HALL @ NYU  Manhattan
# 60823  50103447                                        PLAYA BOWLS  Manhattan
# 60824  50050190                                         SWEETGREEN  Manhattan
#
# ...
