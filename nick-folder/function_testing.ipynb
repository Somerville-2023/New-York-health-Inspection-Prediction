# %%
# %load_ext autoreload
# %autoreload 2

import nick_prepare as p
import nick_acquire as a

import pandas as pd
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/nickolaspedrimiranda/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/nickolaspedrimiranda/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
ny = p.final_ny()

# %%
ny.head()
# Out:
#       camis       dba      boro       phone          inspection_date  \
# 0  41168748    DUNKIN     Bronx  7188614171  2022-03-30T00:00:00.000
# 1  41688142  TABLE 87  Brooklyn  9176186100  2017-01-25T00:00:00.000
# 2  50100336    SUBWAY  Brooklyn  7186808808  2022-04-05T00:00:00.000
# 3  50086686    GERTIE  Brooklyn  7186360902  2021-08-25T00:00:00.000
# 4  50081121    DUNKIN  Brooklyn  7182729090  2022-04-04T00:00:00.000
#
#     latitude  longitude cuisine_description            action  score grade  \
# 0  40.816753 -73.892364              Donuts  Violations cited     13     A
# 1  40.683447 -73.975691               Pizza     No violations      0     A
# 2  40.622569 -74.031412          Sandwiches  Violations cited     10     A
# 3  40.712360 -73.955419            American     No violations      0     A
# 4  40.666827 -73.871606              Donuts  Violations cited     24     B
#
#                   full_address       violation_code  \
# ...

# %%
api_reviews = pd.read_csv('reviews_progress.csv')
scrape_reviews = pd.read_csv('scraped_reviews.csv')

# %%
reviews = p.cleanse_reviews(scrape_reviews, api_reviews)

# %%
ny_reviews = p.ny_pipeline(ny, reviews)

# %%
ny_reviews
# Out:
#           camis                    dba      boro       phone inspection_date  \
# 53458  30075445  MORRIS PARK BAKE SHOP     Bronx  7188924968      2021-08-10
# 36355  30075445  MORRIS PARK BAKE SHOP     Bronx  7188924968      2023-01-31
# 35589  30075445  MORRIS PARK BAKE SHOP     Bronx  7188924968      2023-02-03
# 26194  30075445  MORRIS PARK BAKE SHOP     Bronx  7188924968      2023-08-01
# 57252  30075445  MORRIS PARK BAKE SHOP     Bronx  7188924968      2023-08-22
# ...         ...                    ...       ...         ...             ...
# 19539  50143007             CHILL OUT!    Queens  6469197348      2023-10-24
# 14322  50143038            ZEN KITCHEN  Brooklyn  7187999134      2023-10-18
# 2377   50143057        HANDFIELD HOUSE    Queens  7184873085      2023-10-23
# 26967  50143179     TRUCK STOP KITCHEN    Queens  7183169720      2023-10-17
# 9941   50143179     TRUCK STOP KITCHEN    Queens  7183169720      2023-10-23
#
# ...
