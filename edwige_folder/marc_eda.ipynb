# %% [markdown]
# # Marc EDA Notebook

# %% [markdown]
# * I am going to take the cleaned up information that Nick and I ended up with and explore on it.

# %%
import sys
print(sys.path)
# Out:
# ['/Users/marc_aradillas/codeup-data-science/New-York-health-Inspection-Prediction/marc-folder', '/opt/homebrew/anaconda3/lib/python310.zip', '/opt/homebrew/anaconda3/lib/python3.10', '/opt/homebrew/anaconda3/lib/python3.10/lib-dynload', '', '/opt/homebrew/anaconda3/lib/python3.10/site-packages']

# %%
# import libs
import acquire as a
import prepare as p
import pandas as pd
# I may come up with model and explore .py modules

# %% [markdown]
# # Data Acquisition

# %% [markdown]
# ### We acquired from the Open Data new york using the Socrata API and saw our observations/features

# %%
ny_df = a.acquire_ny()
ny_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207929 entries, 0 to 207928
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   camis                  207929 non-null  int64
#  1   dba                    207421 non-null  object
#  2   boro                   207929 non-null  object
#  3   building               207578 non-null  object
#  4   street                 207923 non-null  object
#  5   zipcode                205249 non-null  float64
#  6   phone                  207922 non-null  object
#  7   inspection_date        207929 non-null  object
#  8   critical_flag          207929 non-null  object
#  9   record_date            207929 non-null  object
#  10  latitude               207672 non-null  float64
#  11  longitude              207672 non-null  float64
#  12  community_board        204682 non-null  float64
#  13  council_district       204678 non-null  float64
#  14  census_tract           204678 non-null  float64
#  15  bin                    203692 non-null  float64
#  16  bbl                    207356 non-null  float64
#  17  nta                    204682 non-null  object
#  18  cuisine_description    205624 non-null  object
#  19  action                 205624 non-null  object
#  20  violation_code         204477 non-null  object
#  21  violation_description  204477 non-null  object
#  22  score                  198223 non-null  float64
#  23  grade                  102176 non-null  object
#  24  grade_date             93423 non-null   object
#  25  inspection_type        205624 non-null  object
# dtypes: float64(9), int64(1), object(16)
# memory usage: 41.2+ MB

# %%
ny_df.describe()
# Out:
#               camis        zipcode       latitude      longitude  \
# count  2.079290e+05  205249.000000  207672.000000  207672.000000
# mean   4.754730e+07   10708.297531      40.202137     -72.989116
# std    4.030975e+06     594.575056       4.592017       8.336484
# min    3.007544e+07    8512.000000       0.000000     -74.249101
# 25%    4.164752e+07   10023.000000      40.682891     -73.988840
# 50%    5.006672e+07   11101.000000      40.730123     -73.956354
# 75%    5.010666e+07   11231.000000      40.760953     -73.896137
# max    5.014367e+07   12345.000000      40.912822       0.000000
#
#        community_board  council_district   census_tract           bin  \
# count    204682.000000     204678.000000  204678.000000  2.036920e+05
# mean        254.466377         20.829606   30102.818036  2.575328e+06
# std         129.962408         15.822260   31625.361472  1.345550e+06
# min         101.000000          1.000000     100.000000  1.000000e+06
# 25%         106.000000          4.000000    8000.000000  1.050759e+06
# 50%         302.000000         20.000000   17500.000000  3.021815e+06
# 75%         401.000000         34.000000   42600.000000  4.006920e+06
# max         595.000000         51.000000  162100.000000  5.799501e+06
#
#                 bbl          score
# count  2.073560e+05  198223.000000
# mean   2.463837e+09      22.745595
# std    1.336137e+09      17.508178
# min    1.000000e+00       0.000000
# 25%    1.010898e+09      11.000000
# 50%    3.007980e+09      19.000000
# 75%    4.004711e+09      30.000000
# max    5.270001e+09     168.000000

# %%
ny_df.head()
# Out:
#       camis                           dba           boro building  \
# 0  50106756  UNGARO COAL FIRED PIZZA CAFE  Staten Island     1298
# 1  50105716                      STELLA'S       Brooklyn      559
# 2  41168748                        DUNKIN          Bronx      880
# 3  50131566                 EXTACY LOUNGE         Queens     7701
# 4  50128764                  RUNNING KIDS       Brooklyn      856
#
#             street  zipcode       phone          inspection_date  \
# 0    FOREST AVENUE  10302.0  6464690930  1900-01-01T00:00:00.000
# 1         5 AVENUE  11215.0  4155703174  1900-01-01T00:00:00.000
# 2  GARRISON AVENUE  10474.0  7188614171  2022-03-30T00:00:00.000
# 3      JAMAICA AVE  11421.0  3478752367  1900-01-01T00:00:00.000
# 4        64 STREET  11220.0  7188338856  1900-01-01T00:00:00.000
#
#     critical_flag              record_date  ...           bbl   nta  \
# 0  Not Applicable  2023-10-26T06:00:14.000  ...  5.003870e+09  SI07
# 1  Not Applicable  2023-10-26T06:00:14.000  ...  3.010480e+09  BK37
# 2    Not Critical  2023-10-26T06:00:11.000  ...  2.027390e+09  BX27
# 3  Not Applicable  2023-10-26T06:00:14.000  ...  4.088410e+09  QN53
# 4  Not Applicable  2023-10-26T06:00:14.000  ...  3.057420e+09  BK34
#
#    cuisine_description                                           action  \
# 0                  NaN                                              NaN
# 1                  NaN                                              NaN
# 2               Donuts  Violations were cited in the following area(s).
# 3                  NaN                                              NaN
# 4                  NaN                                              NaN
#
#    violation_code      violation_description  score grade  \
# 0             NaN                        NaN    NaN   NaN
# 1             NaN                        NaN    NaN   NaN
# 2             10J  Hand wash sign not posted   13.0     A
# 3             NaN                        NaN    NaN   NaN
# 4             NaN                        NaN    NaN   NaN
#
#                 grade_date                        inspection_type
# 0                      NaN                                    NaN
# 1                      NaN                                    NaN
# 2  2022-03-30T00:00:00.000  Cycle Inspection / Initial Inspection
# 3                      NaN                                    NaN
# 4                      NaN                                    NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# - We cleaned up the data by handling all null values, Most nulls were dropped, grades were just adjusted according to score.
# - Nick is currently wanting to accomplish the following:
#     - ***"I want to consolidate the data down to one row per inspection. Currently there are multiple rows per violation per inspection. I would like to merge each row per inspection down to one row."***
#     - ***"Having some difficulties combining rows. I have managed to have some progress using group by along with some aggregate functions. Need to check if combined data is accurate."***

# %% [markdown]
# # Data Preparation

# %% [markdown]
# - Changes:
#     - Function uses an additional line of code that resets index after clean actions.

# %%
ny = p.clean_ny(ny_df)

# %%
ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198289 entries, 0 to 198288
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   camis                  198289 non-null  int64
#  1   dba                    198289 non-null  object
#  2   boro                   198289 non-null  object
#  3   building               198289 non-null  object
#  4   street                 198289 non-null  object
#  5   zipcode                198289 non-null  int64
#  6   phone                  198289 non-null  object
#  7   inspection_date        198289 non-null  datetime64[ns]
#  8   record_date            198289 non-null  object
#  9   latitude               198289 non-null  float64
#  10  longitude              198289 non-null  float64
#  11  cuisine_description    198289 non-null  object
#  12  action                 198289 non-null  object
#  13  violation_code         198289 non-null  object
#  14  violation_description  198289 non-null  object
#  15  score                  198289 non-null  float64
#  16  grade                  198289 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(11)
# memory usage: 25.7+ MB

# %%
ny.describe()
# Out:
#               camis        zipcode                inspection_date  \
# count  1.982890e+05  198289.000000                         198289
# mean   4.749308e+07   10573.075481  2022-05-23 03:45:48.951277824
# min    3.007544e+07       0.000000            2011-10-07 00:00:00
# 25%    4.163804e+07   10022.000000            2022-02-02 00:00:00
# 50%    5.006457e+07   11101.000000            2022-08-29 00:00:00
# 75%    5.010589e+07   11230.000000            2023-03-20 00:00:00
# max    5.014318e+07   12345.000000            2023-10-24 00:00:00
# std    4.056105e+06    1343.223260                            NaN
#
#             latitude      longitude          score
# count  198289.000000  198289.000000  198289.000000
# mean       40.202635     -72.990846      22.702989
# min         0.000000     -74.248708       0.000000
# 25%        40.682327     -73.988899      11.000000
# 50%        40.729928     -73.956452      19.000000
# 75%        40.760760     -73.896122      30.000000
# max        40.912822       0.000000     168.000000
# std         4.588263       8.329762      17.526276

# %% [markdown]
# ### No nulls

# %%
ny.isna().sum()
# Out:
# camis                    0
# dba                      0
# boro                     0
# building                 0
# street                   0
# zipcode                  0
# phone                    0
# inspection_date          0
# record_date              0
# latitude                 0
# longitude                0
# cuisine_description      0
# action                   0
# violation_code           0
# violation_description    0
# score                    0
# grade                    0
# dtype: int64

# %%
ny.nunique()
# Out:
# camis                    25820
# dba                      20593
# boro                         5
# building                  7249
# street                    2256
# zipcode                    221
# phone                    23872
# inspection_date           1613
# record_date                  2
# latitude                 21802
# longitude                21802
# cuisine_description         89
# action                       4
# violation_code              73
# violation_description      151
# score                      130
# grade                        3
# dtype: int64

# %% [markdown]
# ### concatenating the address features together to have a full address column

# %%
full_addy = ny.building + ' ' + ny.street + ' ' + ny.zipcode.astype(str)
ny['full_address'] = full_addy

# %%
ny['full_address'][0:5]
# Out:
# 0      880 GARRISON AVENUE 10474
# 1      620 ATLANTIC AVENUE 11217
# 2            8711 3 AVENUE 11209
# 3          58 MARCY AVENUE 11211
# 4    2492 LINDEN BOULEVARD 11208
# Name: full_address, dtype: object

# %% [markdown]
# - dropped the old address features

# %%
ny = ny.drop(columns=['building', 'street', 'zipcode'])

# %%
ny.columns
# Out:
# Index(['camis', 'dba', 'boro', 'phone', 'inspection_date', 'record_date',
#        'latitude', 'longitude', 'cuisine_description', 'action',
#        'violation_code', 'violation_description', 'score', 'grade',
#        'full_address'],
#       dtype='object')

# %% [markdown]
# ### Now I am looking at the inspections dates for cleaning

# %%
ny.inspection_date.nunique()
# Out:
# 1613

# %% [markdown]
# ## Grouped by camis and inspection_date and then aggregated violation_code and violation description to lists for respective camis/inspection date observation

# %%
agg_violations = ny.groupby(['camis','inspection_date']).agg({'violation_code': lambda x: x.tolist(),'violation_description':lambda x: x.tolist()})
agg_violations[0:2]
# Out:
#                                                     violation_code  \
# camis    inspection_date
# 30075445 2021-08-10                                          [06E]
#          2023-01-31       [04H, 08C, 04L, 10D, 10F, 06C, 04N, 06D]
#
#                                                       violation_description
# camis    inspection_date
# 30075445 2021-08-10       [Sanitized equipment or utensil, including in-...
#          2023-01-31       [Raw, cooked or prepared food is adulterated, ...

# %% [markdown]
# ## Looks good

# %%
# location a specific aggregated violation with specific camis and date
agg_violations.loc[(30075445, '2021-08-10T00:00:00.000')]
# Out:
# violation_code                                                       [06E]
# violation_description    [Sanitized equipment or utensil, including in-...
# Name: (30075445, 2021-08-10 00:00:00), dtype: object

# %% [markdown]
# ## added the codes and descritpion into a list and them appended then to the location for each group (camis/date combination)

# %%
agg_data_code = []
agg_data_description = []

for cam, date in zip(ny.camis, ny.inspection_date):
    agg_data_code.append(agg_violations.loc[(cam, date)][0])
    agg_data_description.append(agg_violations.loc[(cam, date)][1])
    
ny.violation_code = agg_data_code
ny.violation_description = agg_data_description
# Out:
# /var/folders/hz/r10rvhgs41x5bxdmg79hksdw0000gn/T/ipykernel_27479/625493721.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   agg_data_code.append(agg_violations.loc[(cam, date)][0])
# /var/folders/hz/r10rvhgs41x5bxdmg79hksdw0000gn/T/ipykernel_27479/625493721.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   agg_data_description.append(agg_violations.loc[(cam, date)][1])

# %% [markdown]
# ## Look at first 3 to see changes

# %%
ny.head(3)
# Out:
#       camis       dba      boro       phone inspection_date  \
# 0  41168748    DUNKIN     Bronx  7188614171      2022-03-30
# 1  41688142  TABLE 87  Brooklyn  9176186100      2017-01-25
# 2  50100336    SUBWAY  Brooklyn  7186808808      2022-04-05
#
#                record_date   latitude  longitude cuisine_description  \
# 0  2023-10-26T06:00:11.000  40.816753 -73.892364              Donuts
# 1  2023-10-26T06:00:11.000  40.683447 -73.975691               Pizza
# 2  2023-10-26T06:00:11.000  40.622569 -74.031412          Sandwiches
#
#              action   violation_code  \
# 0  Violations cited  [10J, 04N, 08A]
# 1     No violations   [No violation]
# 2  Violations cited  [09B, 10F, 06D]
#
#                                violation_description  score grade  \
# 0  [Hand wash sign not posted, Filth flies or foo...   13.0     A
# 1                                     [No violation]    0.0     A
# 2  [Thawing procedures improper., Non-food contac...   10.0     A
#
#                 full_address
# 0  880 GARRISON AVENUE 10474
# 1  620 ATLANTIC AVENUE 11217
# 2        8711 3 AVENUE 11209

# %% [markdown]
# ## sorting by inspection dates to see if multiple dates are listed for a specific business: this look like it worked we can see the lists in the violation code/description columns

# %%
ny[ny.dba == '$1 PIZZA'].sort_values('inspection_date').head(3)
# Out:
#            camis       dba       boro       phone inspection_date  \
# 146736  50086385  $1 PIZZA  Manhattan  9175878888      2022-02-22
# 162273  50117047  $1 PIZZA  Manhattan  9173883956      2022-05-04
# 150519  50117047  $1 PIZZA  Manhattan  9173883956      2022-05-04
#
#                     record_date   latitude  longitude cuisine_description  \
# 146736  2023-10-26T06:00:11.000  40.746510 -73.990158               Pizza
# 162273  2023-10-26T06:00:11.000  40.731409 -74.001176               Pizza
# 150519  2023-10-26T06:00:11.000  40.731409 -74.001176               Pizza
#
#                   action        violation_code  \
# 146736  Violations cited                 [02B]
# 162273  Violations cited  [06B, 02B, 04A, 06C]
# 150519  Violations cited  [06B, 02B, 04A, 06C]
#
#                                     violation_description  score grade  \
# 146736       [Hot food item not held at or above 140º F.]    7.0     A
# 162273  [Tobacco use, eating, or drinking from open co...    0.0     A
# 150519  [Tobacco use, eating, or drinking from open co...    0.0     A
#
#                              full_address
# 146736                 832 6 AVENUE 10001
# 162273  333B AVENUE OF THE AMERICAS 10014
# 150519  333B AVENUE OF THE AMERICAS 10014

# %%
agg_violations.index[0]
# Out:
# (30075445, Timestamp('2021-08-10 00:00:00'))

# %%
len(agg_data_code)
# Out:
# 198289

# %%
ny.groupby('dba').camis.nunique()
# Out:
# dba
# "U" LIKE CHINESE TAKE OUT           1
# "W" CAFE                            1
# #1 GARDEN CHINESE RESTAURANT        1
# #1 SABOR LATINO RESTAURANT          1
# $1 PIZZA                            2
#                                    ..
# jackies best italian pizza llc      1
# kampai hibachi & brazilian Grill    1
# kokomo restaurant                   1
# matchpointnyc                       1
# mukbang                             1
# Name: camis, Length: 20593, dtype: int64

# %%
ny.head(3)
# Out:
#       camis       dba      boro       phone inspection_date  \
# 0  41168748    DUNKIN     Bronx  7188614171      2022-03-30
# 1  41688142  TABLE 87  Brooklyn  9176186100      2017-01-25
# 2  50100336    SUBWAY  Brooklyn  7186808808      2022-04-05
#
#                record_date   latitude  longitude cuisine_description  \
# 0  2023-10-26T06:00:11.000  40.816753 -73.892364              Donuts
# 1  2023-10-26T06:00:11.000  40.683447 -73.975691               Pizza
# 2  2023-10-26T06:00:11.000  40.622569 -74.031412          Sandwiches
#
#              action   violation_code  \
# 0  Violations cited  [10J, 04N, 08A]
# 1     No violations   [No violation]
# 2  Violations cited  [09B, 10F, 06D]
#
#                                violation_description  score grade  \
# 0  [Hand wash sign not posted, Filth flies or foo...   13.0     A
# 1                                     [No violation]    0.0     A
# 2  [Thawing procedures improper., Non-food contac...   10.0     A
#
#                 full_address
# 0  880 GARRISON AVENUE 10474
# 1  620 ATLANTIC AVENUE 11217
# 2        8711 3 AVENUE 11209

# %%
ny.shape
# Out:
# (198289, 15)

# %% [markdown]
# ## We need to ensure datatypes are correct

# %%
ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198289 entries, 0 to 198288
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   camis                  198289 non-null  int64
#  1   dba                    198289 non-null  object
#  2   boro                   198289 non-null  object
#  3   phone                  198289 non-null  object
#  4   inspection_date        198289 non-null  datetime64[ns]
#  5   record_date            198289 non-null  object
#  6   latitude               198289 non-null  float64
#  7   longitude              198289 non-null  float64
#  8   cuisine_description    198289 non-null  object
#  9   action                 198289 non-null  object
#  10  violation_code         198289 non-null  object
#  11  violation_description  198289 non-null  object
#  12  score                  198289 non-null  float64
#  13  grade                  198289 non-null  object
#  14  full_address           198289 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(10)
# memory usage: 22.7+ MB

# %% [markdown]
# ## There were 89 NaN values for phone, so i will input a string for these and list them as 'no phone'

# %%
# # Convert a numeric column to numeric type (float)
# ny['phone'] = pd.to_numeric(ny['phone'], errors='coerce')

# # Convert it to an integer
# ny['phone'] = ny['phone'].astype(int)

# # Check the data type of the column after conversion
# print(ny['phone'].dtype)

# %%
ny[ny['phone'].isna()].shape
# Out:
# (0, 15)

# %%
ny[ny['phone'].isna()]
# Out:
# Empty DataFrame
# Columns: [camis, dba, boro, phone, inspection_date, record_date, latitude, longitude, cuisine_description, action, violation_code, violation_description, score, grade, full_address]
# Index: []

# %%
# Replace NaN values in the 'phone' column with No Phone place holder
ny['phone'].fillna(-1, inplace=True)  # Use -1 as a numeric placeholder for missing phone numbers

# Check to verify that NaN values have been replaced
print(ny['phone'])
# Out:
# 0         7188614171
# 1         9176186100
# 2         7186808808
# 3         7186360902
# 4         7182729090
#              ...
# 198284    7182973450
# 198285    6464921148
# 198286    2123672192
# 198287    2124803880
# 198288    7185958192
# Name: phone, Length: 198289, dtype: object

# %%
# Convert inspection_date to datetime
ny['inspection_date'] = pd.to_datetime(ny['inspection_date'])

# Convert record_date to datetime
ny['record_date'] = pd.to_datetime(ny['record_date'])

# Convert score to numeric (float)
ny['score'] = pd.to_numeric(ny['score'], errors='coerce')  # 'coerce' to handle non-numeric values

# Convert grade to categorical
ny['grade'] = pd.Categorical(ny['grade'])

# Convert other object columns to appropriate data types as needed
# For example, if 'phone' should be treated as a string, no further conversion is necessary

# Check data types of the DataFrame after conversion
print(ny.dtypes)
# Out:
# camis                             int64
# dba                              object
# boro                             object
# phone                            object
# inspection_date          datetime64[ns]
# record_date              datetime64[ns]
# latitude                        float64
# longitude                       float64
# cuisine_description              object
# action                           object
# violation_code                   object
# violation_description            object
# score                           float64
# grade                          category
# full_address                     object
# dtype: object

# %%
ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198289 entries, 0 to 198288
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   camis                  198289 non-null  int64
#  1   dba                    198289 non-null  object
#  2   boro                   198289 non-null  object
#  3   phone                  198289 non-null  object
#  4   inspection_date        198289 non-null  datetime64[ns]
#  5   record_date            198289 non-null  datetime64[ns]
#  6   latitude               198289 non-null  float64
#  7   longitude              198289 non-null  float64
#  8   cuisine_description    198289 non-null  object
#  9   action                 198289 non-null  object
#  10  violation_code         198289 non-null  object
#  11  violation_description  198289 non-null  object
#  12  score                  198289 non-null  float64
#  13  grade                  198289 non-null  category
#  14  full_address           198289 non-null  object
# dtypes: category(1), datetime64[ns](2), float64(3), int64(1), object(8)
# memory usage: 21.4+ MB

# %% [markdown]
# ## Flattened the DF in case Nick wants to use it.
#
# ## - This has almost 5 Million observations to explore

# %%
# # copy of the original DataFrame
# flattened_ny = ny.copy()

# # Explode the lists in 'violation_code' and 'violation_description' columns
# flattened_ny = flattened_ny.explode('violation_code').explode('violation_description')

# # Reset the index to ensure unique row identifiers
# flattened_ny = flattened_ny.reset_index(drop=True)

# %%
# flattened_ny.info()

# %%
# print(flattened_ny.shape)
# print('\n\n\n')
# flattened_ny.head()

# %% [markdown]
# <!-- ## John Requested Matching Criteria   -->

# %% [markdown]
# # Exploratory Data Analysis - Statistical Analysis

# %%
import pandas as pd
# ny = a.acquire_ny()
# ny = p.final_ny()
import marc_explore as e

# %%
ny = pd.read_csv('clean_ny.csv')

# %%
## Here I am using the cleaned dataframe

# %%
# datetime needs to be applied to date time data
ny['inspection_date'] = pd.to_datetime(ny['inspection_date'])

# %%
ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60825 entries, 0 to 60824
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   camis                  60825 non-null  int64
#  1   dba                    60825 non-null  object
#  2   boro                   60825 non-null  object
#  3   phone                  60825 non-null  int64
#  4   inspection_date        60825 non-null  datetime64[ns]
#  5   latitude               60825 non-null  float64
#  6   longitude              60825 non-null  float64
#  7   cuisine_description    60825 non-null  object
#  8   action                 60825 non-null  object
#  9   score                  60825 non-null  int64
#  10  grade                  60825 non-null  object
#  11  full_address           60825 non-null  object
#  12  violation_code         60825 non-null  object
#  13  violation_description  60825 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(8)
# memory usage: 6.5+ MB

# %%
ny.head(2)
# Out:
#       camis       dba      boro       phone inspection_date   latitude  \
# 0  41168748    DUNKIN     Bronx  7188614171      2022-03-30  40.816753
# 1  41688142  TABLE 87  Brooklyn  9176186100      2017-01-25  40.683447
#
#    longitude cuisine_description            action  score grade  \
# 0 -73.892364              Donuts  Violations cited     13     A
# 1 -73.975691               Pizza     No violations      0     A
#
#                 full_address violation_code  \
# 0  880 GARRISON AVENUE 10474    10J 04N 08A
# 1  620 ATLANTIC AVENUE 11217   No violation
#
#                                violation_description
# 0  Hand wash sign not posted Filth flies or food/...
# 1                                       No violation

# %% [markdown]
# ## Installed Plotly for interactive visuals

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /opt/homebrew/anaconda3/lib/python3.10/site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /opt/homebrew/anaconda3/lib/python3.10/site-packages (from plotly) (23.1)
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
# visual imports
import seaborn as sns
import matplotlib.pyplot as plt
import plotly

import numpy as np

# %% [markdown]
# ## Doing some seaborn exploration

# %% [markdown]
#   * note that I am using the flattened_ny dataframe due to data not being able to be visualized with list values for violation code/description column

# %%
# # should drop lat and long; don't need to see them
# ny = ny.drop(columns=(['latitude', 'longitude']))

# # Separate columns into numeric and categorical types
# numeric_columns = ny.select_dtypes(include=['int64', 'float64']).columns
# categorical_columns = ny.select_dtypes(include=['object']).columns

# # Visualize numeric features (e.g., histograms)
# for column in numeric_columns:
#     plt.figure()
#     sns.histplot(ny[column])
#     plt.title(f'Distribution of {column}')
#     plt.show()

# # Visualize categorical features (e.g., bar plots)
# for column in categorical_columns:
#     plt.figure(figsize=(10, 5))
#     sns.countplot(data=ny, x=column)
#     plt.title(f'Distribution of {column}')
#     plt.xticks(rotation=45)  # Rotate x-axis labels for readability
#     plt.show()

# %% [markdown]
# ## I found that distributions were good for some features but for dba, violation code, violations descriptions, cuisine_description, inspection_type, and full_address was either too difficult to read the x labels or the visuals looks like so many bars and seemed very short.

# %%
ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60825 entries, 0 to 60824
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   camis                  60825 non-null  int64
#  1   dba                    60825 non-null  object
#  2   boro                   60825 non-null  object
#  3   phone                  60825 non-null  int64
#  4   inspection_date        60825 non-null  datetime64[ns]
#  5   latitude               60825 non-null  float64
#  6   longitude              60825 non-null  float64
#  7   cuisine_description    60825 non-null  object
#  8   action                 60825 non-null  object
#  9   score                  60825 non-null  int64
#  10  grade                  60825 non-null  object
#  11  full_address           60825 non-null  object
#  12  violation_code         60825 non-null  object
#  13  violation_description  60825 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(8)
# memory usage: 6.5+ MB

# %% [markdown]
# ## Cleaned the visuals up and the code is listed below

# %%
# Should drop 'latitude' and 'longitude'
# flattened_ny = flattened_ny.drop(columns=['latitude', 'longitude'])

sns.set(font_scale=1.10, style="white")

# Define the list of categorical columns
categorical_columns = ['score', 'boro', 'cuisine_description', 'action']

# Define the list of numerical columns
numerical_columns = ['camis', 'phone', 'inspection_date', 'score']

# Visualize categorical features with horizontal bar plots
for column in categorical_columns:
    plt.figure(figsize=(18, 24))  # Adjust the figure size as needed
    sns.countplot(data=ny, y=column)  # Swap x and y axes
    plt.title(f'Distribution of {column}')
    plt.show()

# Visualize numerical features with horizontal bar plots
for column in numerical_columns:
    plt.figure(figsize=(18, 8))
    sns.histplot(data=ny, x=column)
    plt.title(f'Distribution of {column}')
    plt.show()

# %% [markdown]
# ## Now i will do a pair plot and look at the results for numerical features

# %%
sns.set(font_scale=1, style="white")

sns.pairplot(ny, corner=True)
plt.show()

# %% [markdown]
# ## Histplot of scores

# %%
sns.set(font_scale=1, style="white")

sns.histplot(data=ny, x='score', bins=25)
plt.title('Distribution of data by Scores', fontsize=15)
plt.xlabel('Score', labelpad=20)
plt.ylabel('Count', rotation=0, labelpad=30)
plt.xlim(0, 80)
plt.ylim(0,28000)
plt.show()

# %% [markdown]
# ## Data distribution test for mvp

# %%
import marc_explore as e

e.data_distribution(ny)

# %% [markdown]
# ## Histplot of Grades

# %%
sns.set(font_scale=1, style="white")

sns.histplot(data=ny, x='grade')
plt.title('Grades on Health Inspections', fontsize=15)
plt.xlabel('Grades', labelpad=20)
plt.ylabel('Count', rotation=0, labelpad=30)
plt.show()

# %% [markdown]
# ## Borough counts

# %%
sns.set(font_scale=1, style="white")

sns.histplot(data=ny, x='boro', bins=20)
plt.title('NY Boro Restaurant Inspections', fontsize=15)
plt.xlabel('Boroughs', labelpad=20)
plt.ylabel('Count', rotation=0, labelpad=30)
plt.show()

# %%
sns.set(font_scale=1, style="white")

# Assuming 'ny' is your DataFrame
plt.figure(figsize=(12, 8))

sns.histplot(data=ny, y='score', bins=20, hue='boro', multiple='stack', palette='viridis', shrink=0.8)

plt.title('NY Boro Restaurant Inspections', fontsize=15)
plt.xlabel('Count', labelpad=20)
plt.ylabel('Score', rotation=0, labelpad=30)

plt.show()

# %% [markdown]
# ## observing score and grade relationship; seems that the lower the score the letter grade is closer to A

# %%
import matplotlib.pyplot as plt

sns.set(font_scale=1, style="white")

ny_score = ny['score'].sort_values(ascending=False)

sns.barplot(data=ny, x = ny_score, y = 'boro', ci =None)
plt.title('Average Violation Score by Borough', fontsize=15)
plt.xlabel('Violation Score', labelpad=0)
plt.ylabel('Boroughs', labelpad=0)
plt.savefig('boros.png', transparent=True)
plt.show()

# %% [markdown]
# ## Too many to visual need to bring it down to at least top 20

# %%
# business counts
dba_count = ny['dba'].value_counts()
dba_count

# %%
top_20 = dba_count[0:20]
top_20

# %% [markdown]
# ## Found large chain restaurants as top names for health inspections conducted

# %%
import warnings
warnings.filterwarnings("ignore")

sns.set(font_scale=4, style='white')

top_n = 20  # Adjust the number of top values to display

# Create a figure and specify the desired figure size
plt.figure(figsize=(36, 20))

# Create the countplot with y as the 'dba' and x as the count
countplot = sns.countplot(data=ny, y='dba', order=ny['dba'].value_counts().iloc[:top_n].index)

# Increase the font size for the title and y-axis labels
countplot.set_yticklabels(countplot.get_yticklabels(), fontsize=25)  # Adjust the fontsize as needed
plt.title(f'Top {top_n} Businesses by count', fontsize=50)  # Adjust the fontsize as needed
plt.ylabel('')
plt.xlabel('')

plt.show()

# %%
e.visual_1(ny)

# %% [markdown]
# ## I have hued by grade to see where scores fall

# %%
# Set the font scale and style
sns.set(font_scale=1, style="white")

ny_scores = ny[ny.score < 80]
# Create a histogram with a hue variable
sns.histplot(data=ny_scores, x='score', hue='grade', bins=20)
plt.title('Grades on Health Inspections', fontsize=15)
plt.xlabel('Grades', labelpad=20)
plt.ylabel('Count', rotation=0, labelpad=30)
plt.show()

# %% [markdown]
# ## What was the top cuisine description of inspected restaurants?

# %%
ny.cuisine_description.value_counts()

# %%
import warnings
warnings.filterwarnings("ignore")

sns.set(font_scale=4, style='white')

top_n = 20  # Adjust the number of top values to display

# Create a figure and specify the desired figure size
plt.figure(figsize=(36, 20))

# Create the countplot with y as the 'dba' and x as the count
countplot = sns.countplot(data=ny, y='cuisine_description', order=ny['cuisine_description'].value_counts().iloc[:top_n].index)

# Increase the font size for the title and y-axis labels
countplot.set_yticklabels(countplot.get_yticklabels(), fontsize=25)  # Adjust the fontsize as needed
plt.title(f'Top {top_n} Cuisine by count', fontsize=50)  # Adjust the fontsize as needed
plt.ylabel('')
plt.xlabel('')
plt.show()

# %% [markdown]
# ## visual one for mvp

# %%
e.visual_2(ny)

# %% [markdown]
# ## What would grades for the top 20 business in this data be?

# %%
top_20_dba = ny['dba'].value_counts().head(20).index
top_20_dba

# %%
# Set the font scale and style
sns.set(font_scale=0.95, style="white")

# Get the top 20 businesses by counting the "dba" values
top_20_dba = ny['dba'].value_counts().head(20).index

# Filter the data to include only scores less than 80
ny_scores = ny[ny['score'] < 80]

# Group the data by 'dba' and 'grade' and count the occurrences
grouped_data = ny_scores[ny_scores['dba'].isin(top_20_dba)].groupby(['dba', 'grade']).size().unstack(fill_value=0)

# Sort the data by total counts for each business in descending order
sorted_data = grouped_data.sum(axis=1).sort_values(ascending=True).index

# Create a horizontal grouped bar plot with ascending bars
plt.figure(figsize=(12, 8))
ax = grouped_data.loc[sorted_data].plot(kind='barh', stacked=True, legend=False)

plt.title('Grades for Top 20 Businesses', fontsize=15)
plt.ylabel('Business Names', rotation=0, labelpad=20)
plt.xlabel( '', rotation=0, labelpad=20)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are offplt.legend()
plt.legend(title='Grades')
plt.show()

# %% [markdown]
# ## What were the top violation code counted?

# %%
# Initialize an empty list to store the split codes
split_codes_list = []

# Access the column with the codes
codes_column = ny['violation_code']

# Split the codes and append them to the list
for codes in codes_column:
    
    if codes == 'No violation':
        split_codes_list.append(codes)
        
    else:
        split_codes = codes.split(' ')
        
        split_codes_list.extend(split_codes)


# Now, split_codes_list contains all the split codes

# You can print the list to verify the results
print(split_codes_list[0:100])

# %%
# truen list into a sereis 
violation_code_series = pd.Series(split_codes_list)
#get value_counts for ech code
violation_code_series.value_counts()

# %%
violation_counts = violation_code_series.value_counts().reset_index()
violation_counts.columns = ['Violation Code', 'Count']

plt.figure(figsize=(12, 15))
sns.set(font_scale=1, style="white")
sns.barplot(data=violation_counts, x='Count', y='Violation Code')
plt.xlabel('Count')
plt.ylabel('Violation Code')
plt.title('Count of Violation Codes')
plt.show()

# %% [markdown]
# ## The most occurring violation code in out data was 10F, here are what the violations were:
# * Flooring improperly constructed and/or maintained
# * Non-food contact surfaces (wall, ceiling, floors) improperly constructed/maintained
# * Non-food contact surface (fixtures, decorative material, fans, etc.) not properly maintained or equipment not properly maintained

# %% [markdown]
#   ## Cuisine Type vs. Score

# %%
sns.set(font_scale=0.95, style="white")

plt.figure(figsize=(6,24))  # Adjust the figure size as needed

ny = ny.sort_values(by='score', ascending=False)

sns.barplot(data=ny, x='score', y='cuisine_description', color='lightgreen', ci=False)
    
plt.xlabel('Score')
plt.xticks()  # Rotate x-axis labels for better visibility
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are offplt.legend()
plt.ylabel('Cuisine Type', rotation=0, labelpad=30)
plt.title(' Cuisine Type vs. Score')
plt.show()

# %% [markdown]
# ## The Top 20 Scores (failing) by Borough

# %%
top_20_scores = ny.nlargest(20, 'score')

sns.set(font_scale=1.5, style="white")
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.barplot(data=top_20_scores, x='boro', y='score', hue='action', color='red', ci=False)
plt.xlabel('')
plt.ylabel('Score')
plt.title('Bar Plot of Top 20 Scores by Borough')
plt.xticks(rotation=0)  # Rotate x-axis labels for better visibility
plt.show()

# %% [markdown]
# ## There are restaurants with failing scores that show have received violations cited and still remain an active restaurant

# %%
from scipy import stats

# %% [markdown]
# ### (Independent t-test)
# - **Null Hypothesis (H0): There is no significant difference in health inspection scores between the Bronx and Queens.**
#
# - **Alternative Hypothesis (H1): There is a significant difference in health inspection scores between the Bronx and Queens.**

# %%
scores_bronx = pd.Series(top_20_scores.boro == 'Bronx')
scores_queens = pd.Series(top_20_scores.boro == 'Queens')

# %%
# Perform the t-test
t_statistic, p_value = stats.ttest_ind(scores_bronx, scores_queens)

# Print the results
print(f"t-statistic: {t_statistic}")
print(f"P-value: {p_value}")

# %%
def eval_result(p_value, a = 0.05):
    
    if p_value < a:

        print('Reject the null hypothesis!')
        
    else: 

        print('Failed to reject the null hypothesis!')

# %%
eval_result(p_value)

# %%
# r, p = stats.pearsonr(ny., ny.)

# if p < alpha:
#     print("We reject the null hypothesis")

# else:
#     print("We fail to reject the null hypothesis")

# r, p

# %%
# contingency_table = pd.DataFrame(ny, index=['boro', "score"])
# chi, p, degf, exp = stats.chi2_contingency(contingency_table)

# %%
## function for top 20 businesses for bronx and queens 
e.visual_3(ny)

# %% [markdown]
# ## Scatterplot of score vs. inspection date

# %%
sns.set(font_scale=0.95, style="white")
sns.scatterplot(data=ny, x='score', y='inspection_date')
plt.xlabel('Score', labelpad=20)
plt.ylabel('Years')
plt.title('Scatterplot of Score vs. Inspection Date')
plt.xticks(rotation=0)  # Rotate x-axis labels for better visibility
# plt.tick_params(
#     axis='x',          # changes apply to the x-axis
#     which='both',      # both major and minor ticks are affected
#     bottom=False,      # ticks along the bottom edge are off
#     top=False,         # ticks along the top edge are off
#     labelbottom=False) # labels along the bottom edge are offplt.legend()
plt.show()

# %% [markdown]
# ## Scatterplot of actions outcomes based on score and inspection dates.

# %%
# Convert inspection_date to numeric format (e.g., seconds since the epoch)
ny['inspection_date_numeric'] = ny['inspection_date'].view('int64') // 10**9  # Convert to seconds

# set font and style
sns.set(font_scale=1.25, style="white")

# color corrected the visual
custom_palette = ["red", "orange", "blue", "mediumseagreen"]

# Specify the order and palette for 'action' categories
hue_order = ['Closed', 'Violations cited', 'Re-opened', 'No violations']  # Specify your category names
sns.scatterplot(data=ny, x='score', y='inspection_date', hue='action', hue_order=hue_order, palette=custom_palette)
plt.xlabel('Score', labelpad=20)
plt.ylabel('Years')
plt.title('Health Inspection Scores and Action over time')
plt.show()

# %%
# Calculate the Pearson correlation coefficient and p-value
correlation_coefficient, p_value = stats.pearsonr(ny['inspection_date_numeric'], ny['score'])

print(f"Pearson Correlation Coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")

# Interpret the result
if p_value < 0.05:  # You can choose your desired significance level (alpha)
    print("\nThere is a statistically significant correlation between inspection scores and inspection dates.")
else:
    print("\nThere is no statistically significant correlation between inspection scores and inspection dates.")

# %% [markdown]
# ## testing visual_3 function

# %%
e.visual_4(ny)

# %% [markdown]
# ## We can see that over time we see inspections have been conducted more frequently and see a distinction of closed and active restaurant business over the recent years
# - ***Note: the gap is due to the COVID-19 pandemic***

# %% [markdown]
# ### (Pearson test)
# - **Null Hypothesis (H0): There is no significant difference in health inspection scores between the Bronx and Queens.**
#
# - **Alternative Hypothesis (H1): There is a significant difference in health inspection scores between the Bronx and Queens.**

# %% [markdown]
# ## Noticed that I can just reindex with date time and view data this way

# %%
# Convert inspection_date to datetime and index and sorted the values
ny_time = ny.set_index('inspection_date')
ny_time.head(2)

# %%
ny_time = ny_time.sort_values(by='inspection_date')
ny_time.head(2)

# %%
ny_time.info()

# %%
ny_time.head(1)

# %% [markdown]
# ## Indexing time and plot our features proved uneventful

# %%
ny_time.plot()

# %% [markdown]
# # Finished Explore Functions Here:

# %%
e.data_distribution(ny)

# %%
e.visual_1(ny)

# %%
e.visual_2(ny)

# %%
e.visual_3(ny)

# %%
e.visual_4(ny)

# %% [markdown]
# # Data Modeling
