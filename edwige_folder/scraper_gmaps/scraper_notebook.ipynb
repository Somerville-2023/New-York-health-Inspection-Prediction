# %%
# !python scraper.py --N 200 --i places_scrape_rdy.csv --debug
# Out:
# Scraper initialized successfully.
# IP masking successful: Your IP address is being masked by Tor.
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJ79lG6ylawokRHzGFI0I0V8k
# Attempting to sort reviews...
# Errors while readying to scrape: -1
# Error encountered when sorting reviews for URL: https://www.google.com/maps/place/?q=place_id:ChIJ79lG6ylawokRHzGFI0I0V8k
# The current page count is 1
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJw0ul69tcwokRUXZtYK2viEw
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJw0ul69tcwokRUXZtYK2viEw...
# [Scraping from review 0]
# Number of reviews fetched: 90
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 90]
# Number of reviews fetched: 25
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 115]
# Number of reviews fetched: 0
# No more reviews to fetch. Breaking out of the loop.
# The current page count is 2
# Processing URL: https://www.google.com/maps/place/?q=place_id:ChIJN8ko6jxawokRh4mOVeF82dg
# Attempting to sort reviews...
# Errors while readying to scrape: 0
# Starting to scrape reviews for https://www.google.com/maps/place/?q=place_id:ChIJN8ko6jxawokRh4mOVeF82dg...
# [Scraping from review 0]
# Number of reviews fetched: 90
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# Review written to CSV
# [Scraping from review 90]
# Traceback (most recent call last):
#   File "/Users/edwige/codeup-data-science/capstone/New-York-health-Inspection-Prediction/edwige_folder/scraper_gmaps/scraper.py", line 82, in <module>
#     reviews = scraper.get_reviews(n)
#   File "/Users/edwige/codeup-data-science/capstone/New-York-health-Inspection-Prediction/edwige_folder/scraper_gmaps/googlemaps.py", line 367, in get_reviews
#     self.__expand_reviews_text()
#   File "/Users/edwige/codeup-data-science/capstone/New-York-health-Inspection-Prediction/edwige_folder/scraper_gmaps/googlemaps.py", line 637, in __expand_reviews_text
#     review_blocks = self.driver.find_elements(By.CSS_SELECTOR, 'div.jftiEf.fontBodyMedium')
#   File "/usr/local/anaconda3/envs/j_scraper/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py", line 770, in find_elements
#     return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#   File "/usr/local/anaconda3/envs/j_scraper/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py", line 346, in execute
#     self.error_handler.check_response(response)
#   File "/usr/local/anaconda3/envs/j_scraper/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py", line 229, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: disconnected: not connected to DevTools
#   (failed to check if window was closed: disconnected: not connected to DevTools)
#   (Session info: chrome=120.0.6099.5)
# Stacktrace:
# 0   chromedriver                        0x000000010c452218 chromedriver + 4846104
# 1   chromedriver                        0x000000010c449773 chromedriver + 4810611
# 2   chromedriver                        0x000000010c01779d chromedriver + 411549
# 3   chromedriver                        0x000000010bffbf4e chromedriver + 298830
# 4   chromedriver                        0x000000010bffbe43 chromedriver + 298563
# 5   chromedriver                        0x000000010c01a032 chromedriver + 421938
# 6   chromedriver                        0x000000010c0b0207 chromedriver + 1036807
# 7   chromedriver                        0x000000010c091943 chromedriver + 911683
# 8   chromedriver                        0x000000010c0590a3 chromedriver + 680099
# 9   chromedriver                        0x000000010c05a6be chromedriver + 685758
# 10  chromedriver                        0x000000010c411b32 chromedriver + 4582194
# 11  chromedriver                        0x000000010c416d4c chromedriver + 4603212
# 12  chromedriver                        0x000000010c3f7131 chromedriver + 4473137
# 13  chromedriver                        0x000000010c417ac6 chromedriver + 4606662
# 14  chromedriver                        0x000000010c3e86bc chromedriver + 4413116
# 15  chromedriver                        0x000000010c437bd8 chromedriver + 4738008
# 16  chromedriver                        0x000000010c437d8e chromedriver + 4738446
# 17  chromedriver                        0x000000010c4493b3 chromedriver + 4809651
# 18  libsystem_pthread.dylib             0x00007ff81167a202 _pthread_start + 99
# 19  libsystem_pthread.dylib             0x00007ff811675bab thread_start + 15

# %% [markdown]
# ## Ignore from here down (I use it for testing the script)

# %%
import requests
from googlemaps import GoogleMapsScraper
from selenium.webdriver.common.by import By

# Function to get IP address without using Tor
def get_ip_without_tor():
    response = requests.get('http://httpbin.org/ip')
    ip_without_tor = response.json()['origin']
    print("IP without Tor:", ip_without_tor)
    return ip_without_tor

# Function to get IP address using Tor with the initialized WebDriver
def get_ip_with_tor(scraper):
    scraper.driver.get('http://httpbin.org/ip')
    response_text = scraper.driver.find_element(By.TAG_NAME, 'pre').text
    ip_with_tor = eval(response_text)['origin']
    print("IP with Tor:", ip_with_tor)
    return ip_with_tor

def test_tor_connection():
    print("Testing Tor connection...")

    # Initialize GoogleMapsScraper
    scraper = GoogleMapsScraper()

    # Get IP without Tor
    ip_without_tor = get_ip_without_tor()

    # Get IP with Tor
    ip_with_tor = get_ip_with_tor(scraper)

    # Check if the IP addresses are different
    if ip_without_tor != ip_with_tor:
        print("IP masking successful: Your IP address is being masked by Tor.")
    else:
        print("IP masking unsuccessful: Your IP address is not being masked by Tor.")

    # Close and quit the WebDriver
    # scraper.driver.quit()

    print("Test completed.")

# %%
import os 
os.system('afplay /System/Library/Sounds/Ping.aiff')
# Out:
# 0

# %%
test_tor_connection()
# Out:
# Testing Tor connection...
# IP without Tor: 75.81.146.166
# IP with Tor: 188.68.41.191
# IP masking successful: Your IP address is being masked by Tor.
# Test completed.

# %%
from stem import Signal
from stem.control import Controller
