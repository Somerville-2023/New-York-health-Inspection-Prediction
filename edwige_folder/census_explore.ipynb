# %%
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import census as census
from us import states
import os
import ktn_acquire
from env import census_api_key

# %%
# ktn test
# ktn_acquire.get_profile_data('2023','test','10001')

# %%
# test with using ktn funcitno with ny zipcodes
'''
def get_nyc_demographics_by_zip(zip_code):
    # nyc zip codes
    nyc_zip_codes = ['10001', '10002', '10003', '10004', '10005', '10006', '10007', '10008', '10009', '10010', 
                     '10011', '10012', '10013', '10014', '10015', '10016', '10017', '10018', '10019', '10020', 
                     '10021', '10022', '10023', '10024', '10025', '10026', '10027', '10028', '10029', '10030', 
                     '10031', '10032', '10033', '10034', '10035', '10036', '10037', '10038', '10039', '10040', 
                     '10041', '10044', '10045', '10048', '10055', '10060', '10069', '10075', '10090', '10103', 
                     '10110', '10111', '10112', '10115', '10118', '10119', '10120', '10121', '10122', '10123', 
                     '10128', '10151', '10152', '10153', '10154', '10155', '10158', '10161', '10162', '10165', 
                     '10166', '10167', '10168', '10169', '10170', '10171', '10172', '10173', '10174', '10175', 
                     '10176', '10177', '10178', '10179', '10199', '10270', '10271', '10278', '10279', '10280', 
                     '10281', '10282', '10451', '10452', '10453', '10454', '10455', '10456', '10457', '10458', 
                     '10459', '10460', '10461', '10462', '10463', '10464', '10465', '10466', '10467', '10468', 
                     '10469', '10470', '10471', '10472', '10473', '10474', '10475', '10499', '11004', '11005', 
                     '11101', '11102', '11103', '11104', '11105', '11106', '11109', '11120', '11201', '11202', 
                     '11203', '11204', '11205', '11206', '11207', '11208', '11209', '11210', '11211', '11212', 
                     '11213', '11214', '11215', '11216', '11217', '11218', '11219', '11220', '11221', '11222', 
                     '11223', '11224', '11225', '11226', '11228', '11229', '11230', '11231', '11232', '11233', 
                     '11234', '11235', '11236', '11237', '11238', '11239', '11241', '11242', '11243', '11249', 
                     '11251', '11252', '11351', '11352', '11354', '11355', '11356', '11357', '11358', '11359', 
                     '11360', '11361', '11362', '11363', '11364', '11365', '11366', '11367', '11368', '11369', 
                     '11370', '11371', '11372', '11373', '11374', '11375', '11377', '11378', '11379', '11385', 
                     '11411', '11412', '11413', '11414', '11415', '11416', '11417', '11418', '11419', '11420', 
                     '11421', '11422', '11423', '11424', '11425', '11426', '11427', '11428', '11429', '11430', 
                     '11432', '11433', '11434', '11435', '11436', '11439', '11451', '11452', '11460', '11470', 
                     '11471', '11472', '11474', '11476', '11478', '11480', '11482', '11484', '11486', '11488', 
                     '11499', '11691', '11692', '11693', '11694', '11695', '11697']
    
    if zip_code not in nyc_zip_codes:
        return "The provided zip code is not in New York City."
    
    # fetch the demographic data for the provided zip code
    df = ktn_acquire.acquire_data(zip_code)
    
    return df
    
'''

# %%
# df = get_nyc_demographics_by_zip('10001')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /usr/local/anaconda3/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /usr/local/anaconda3/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /usr/local/anaconda3/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /usr/local/anaconda3/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = get_nyc_demographics_by_zip('10001')
#
# Cell In[10], line 34, in get_nyc_demographics_by_zip(zip_code)
#      31     return "The provided zip code is not in New York City."
#      33 # fetch the demographic data for the provided zip code
# ---> 34 df = ktn_acquire.acquire_data(zip_code)
#      36 return df
#
# File ~/codeup-data-science/capstone/New-York-health-Inspection-Prediction/edwige_folder/ktn_acquire.py:181, in acquire_data(zip_code)
#     179 def acquire_data(zip_code):
# --> 181     df = assemble_group_data(zip_code)
#     183     return process_dp03_data(df)
#
# File ~/codeup-data-science/capstone/New-York-health-Inspection-Prediction/edwige_folder/ktn_acquire.py:139, in assemble_group_data(zip_code, years)
#     135 final_df = pd.DataFrame()
#     137 for year in years:
# --> 139     df = get_pre_2020_profile_data(year, zip_code)
#     141     if len(final_df) == 0:
#     143         final_df = df.copy()
#
# File ~/codeup-data-science/capstone/New-York-health-Inspection-Prediction/edwige_folder/ktn_acquire.py:116, in get_pre_2020_profile_data(year, zip_code, group)
#     112 url = f'https://api.census.gov/data/{year}/acs/acs5/profile?get=group({group})&for=zip%20code%20tabulation%20area:{zip_code}&in=state:48&key={census_api_key}'
#     114 response = get(url)
# --> 116 content = response.json()
#     118 df = pd.DataFrame(content).T
#     120 df.columns=['variable', year]
#
# File /usr/local/anaconda3/lib/python3.10/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
 asc5_2021_dictionary = pd.read_html('https://api.cenasc5_2021_dictionarysus.gov/data/2021/acs/acs5/profile/variables.html')

# %%
asc5_2021_dictionary = asc5_2021_dictionary[0]

# %%
# This is the data dictionary for asc5 2021
asc5_2021_dictionary
# Out:
#                 Name                                       Label  \
# 0             AIANHH                                   Geography
# 1             AIHHTL                                   Geography
# 2              AIRES                                   Geography
# 3               ANRC                                   Geography
# 4               CBSA                                   Geography
# ...              ...                                         ...
# 1388          TTRACT                                   Geography
# 1389              UA                                   Geography
# 1390           ucgid  Uniform Census Geography Identifier clause
# 1391            ZCTA                                   Geography
# 1392  1392 variables                              1392 variables
#
#                                  Concept        Required      Attributes  \
# 0                                    NaN    not required             NaN
# 1                                    NaN    not required             NaN
# 2                                    NaN    not required             NaN
# 3                                    NaN    not required             NaN
# 4                                    NaN    not required             NaN
# ...                                  ...             ...             ...
# 1388                                 NaN    not required             NaN
# 1389                                 NaN    not required             NaN
# 1390  Census API Geography Specification  predicate-only             NaN
# 1391                                 NaN    not required             NaN
# 1392                      1392 variables  1392 variables  1392 variables
#
#                Limit     Predicate Type           Group      Unnamed: 8
# 0                  0  (not a predicate)             NaN             NaN
# 1                  0  (not a predicate)             NaN             NaN
# 2                  0  (not a predicate)             NaN             NaN
# 3                  0  (not a predicate)             NaN             NaN
# 4                  0  (not a predicate)             NaN             NaN
# ...              ...                ...             ...             ...
# 1388               0  (not a predicate)             NaN             NaN
# 1389               0  (not a predicate)             NaN             NaN
# 1390               0              ucgid             NaN             NaN
# 1391               0  (not a predicate)             NaN             NaN
# 1392  1392 variables     1392 variables  1392 variables  1392 variables
#
# [1393 rows x 9 columns]
