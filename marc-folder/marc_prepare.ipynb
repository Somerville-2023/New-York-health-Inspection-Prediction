# %% [markdown]
# # Marc's Prepare

# %%
import pandas as pd
import numpy as np
import os
import requests
import env

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install sodapy

import pandas as pd
from env import API_Key_ID, API_Key_Token, APP_TOKEN, url, password
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
# client = Socrata(url, APP_TOKEN)

#Example authenticated client (needed for non-public datasets):
client = Socrata('data.cityofnewyork.us',
                 APP_TOKEN,
                 username="aradillasm@gmail.com",
                 password=password)

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("43nn-pn8j", limit=500000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.head()
# Out:
#       camis                           dba           boro building  \
# 0  50106756  UNGARO COAL FIRED PIZZA CAFE  Staten Island     1298
# 1  50105716                      STELLA'S       Brooklyn      559
# 2  41168748                        DUNKIN          Bronx      880
# 3  50131566                 EXTACY LOUNGE         Queens     7701
# 4  50128764                  RUNNING KIDS       Brooklyn      856
#
#             street zipcode       phone          inspection_date  \
# 0    FOREST AVENUE   10302  6464690930  1900-01-01T00:00:00.000
# 1         5 AVENUE   11215  4155703174  1900-01-01T00:00:00.000
# 2  GARRISON AVENUE   10474  7188614171  2022-03-30T00:00:00.000
# 3      JAMAICA AVE   11421  3478752367  1900-01-01T00:00:00.000
# 4        64 STREET   11220  7188338856  1900-01-01T00:00:00.000
#
#     critical_flag              record_date  ...         bbl   nta  \
# 0  Not Applicable  2023-10-26T06:00:14.000  ...  5003870033  SI07
# ...

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207929 entries, 0 to 207928
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   camis                  207929 non-null  object
#  1   dba                    207426 non-null  object
#  2   boro                   207929 non-null  object
#  3   building               207587 non-null  object
#  4   street                 207929 non-null  object
#  5   zipcode                205255 non-null  object
#  6   phone                  207922 non-null  object
#  7   inspection_date        207929 non-null  object
#  8   critical_flag          207929 non-null  object
#  9   record_date            207929 non-null  object
#  10  latitude               207672 non-null  object
#  11  longitude              207672 non-null  object
#  12  community_board        204682 non-null  object
#  13  council_district       204678 non-null  object
# ...

# %%
results_df.isna().sum()
# Out:
# camis                         0
# dba                         503
# boro                          0
# building                    342
# street                        0
# zipcode                    2674
# phone                         7
# inspection_date               0
# critical_flag                 0
# record_date                   0
# latitude                    257
# longitude                   257
# community_board            3247
# council_district           3251
# census_tract               3251
# bin                        4237
# bbl                         573
# nta                        3247
# cuisine_description        2305
# action                     2305
# violation_code             3452
# violation_description      3452
# score                      9706
# grade                    105753
# grade_date               114506
# inspection_type            2305
# dtype: int64

# %%
null_mask = results_df.isnull()  # or df.isna()

columns_with_nulls = null_mask.any()  # a Series of True/False for each column

columns_with_null_values = columns_with_nulls[columns_with_nulls].index.tolist()

# columns_with_null_values contains a list of column names with null values
print(columns_with_null_values)

columns_with_nulls.sum()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
